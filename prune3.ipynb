# %%
import pathlib
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
from prepare import process_regressor, model_performance_metrics,draw_scatter
from data_prune_function import get_scores,get_data,prune_rd,return_model

test_size = 0.1

model = {}
for modelname in ['CB','XG','GB']:
    model[modelname] = return_model(modelname,random_state=1)

target = 'NO(%)'
df,X,y,X_train_val,X_test,y_train_val,y_test = get_data(target = target,random_state=13, test_size=test_size,standardized=False)
mad = (y - y.mean()).abs().mean()
std = y.std()
print('')
print('-----------------')
print(f'{target} {y.shape[0]} {mad:.3f} {std:.3f} ')
print('-----------------')
target = 'NO(%)'
a = 'CB'
b = 'XG'
c = 'GB'
# Out:
# -----------------
# NO(%) 242 14.156 17.853
# -----------------

# %%
folder = f'{target}/{target}_{a}_guiding_pruning'
pathlib.Path(f"./{folder}").mkdir(parents=True, exist_ok=True)
file_out_a = f'{folder}/all_dat.pkl'

folder = f'{target}/{target}_{b}_guiding_pruning'
pathlib.Path(f"./{folder}").mkdir(parents=True, exist_ok=True)
file_out_b = f'{folder}/all_dat.pkl'

folder = f'{target}/{target}_{c}_guiding_pruning'
pathlib.Path(f"./{folder}").mkdir(parents=True, exist_ok=True)
file_out_c = f'{folder}/all_dat.pkl'

# %%
maes_a, rmse_a, r2_a = get_scores(model[a], X_train_val, y_train_val, X_test, y_test)
maes_b, rmse_b, r2_b = get_scores(model[b], X_train_val, y_train_val, X_test, y_test)
maes_c, rmse_c, r2_c = get_scores(model[c], X_train_val, y_train_val, X_test, y_test)
# Out:
# Test scores: MAE=6.200, RMSE=8.569, R2=0.845
# --- 0.7705340385437012 seconds ---
#
# Test scores: MAE=7.014, RMSE=8.931, R2=0.831
# --- 0.08842325210571289 seconds ---
#
# Test scores: MAE=6.380, RMSE=9.015, R2=0.828
# --- 0.11274933815002441 seconds ---

# %%
size_old_val_a, ids_a, test_scores_a, val_scores_a,test_fit_a,remove_a = prune_rd(
        model[a], X_train_val, y_train_val, X_test, y_test,max_iter=80,
        min_drop= 2,
        threshold=maes_a / 2,train_size= 0.9, file_out=file_out_a)
# Out:
# ================================
# Iteration 0:
# 丢弃训练词条数量 : 8
# 本次循环中 old_val 数量: 0 (ratio = 0.000)
# 本次循环中新训练集大小，占比: 217  (ratio = 1.000)
# --- 0.7910785675048828 seconds ---
# 修剪模型：
# Test scores: maes=6.080, rmse=8.324, r2=0.854
# --- 0.6843287944793701 seconds ---
# ================================
# Iteration 1:
# 丢弃训练词条数量 : 6
# 本次循环中 old_val 数量: 8 (ratio = 0.037)
# 本次循环中新训练集大小，占比: 209  (ratio = 0.963)
# --- 0.6923420429229736 seconds ---
# 修剪模型：
# Test scores: maes=6.213, rmse=8.407, r2=0.851
# Val scores: maes=2.170, rmse=2.915, r2=0.953
# --- 0.6945183277130127 seconds ---
# ================================
# Iteration 2:
# 丢弃训练词条数量 : 7
# 本次循环中 old_val 数量: 14 (ratio = 0.065)
# 本次循环中新训练集大小，占比: 203  (ratio = 0.935)
# --- 0.7062711715698242 seconds ---
# 修剪模型：
# Test scores: maes=6.027, rmse=8.269, r2=0.855
# Val scores: maes=1.777, rmse=2.402, r2=0.974
# --- 0.683495044708252 seconds ---
# ================================
# Iteration 3:
# 丢弃训练词条数量 : 4
# 本次循环中 old_val 数量: 21 (ratio = 0.097)
# 本次循环中新训练集大小，占比: 196  (ratio = 0.903)
# --- 0.6833500862121582 seconds ---
# 修剪模型：
# Test scores: maes=6.296, rmse=8.590, r2=0.844
# Val scores: maes=1.641, rmse=2.316, r2=0.966
# --- 0.7131936550140381 seconds ---
# ================================
# Iteration 4:
# 丢弃训练词条数量 : 6
# 本次循环中 old_val 数量: 25 (ratio = 0.115)
# 本次循环中新训练集大小，占比: 192  (ratio = 0.885)
# --- 0.6510534286499023 seconds ---
# 修剪模型：
# Test scores: maes=6.090, rmse=8.260, r2=0.856
# Val scores: maes=2.031, rmse=2.740, r2=0.949
# --- 0.7238311767578125 seconds ---
# ================================
# Iteration 5:
# 丢弃训练词条数量 : 5
# 本次循环中 old_val 数量: 31 (ratio = 0.143)
# 本次循环中新训练集大小，占比: 186  (ratio = 0.857)
# --- 0.7450771331787109 seconds ---
# 修剪模型：
# Test scores: maes=6.143, rmse=8.205, r2=0.858
# Val scores: maes=2.256, rmse=2.915, r2=0.947
# --- 0.7704706192016602 seconds ---
# ================================
# Iteration 6:
# 丢弃训练词条数量 : 6
# 本次循环中 old_val 数量: 36 (ratio = 0.166)
# 本次循环中新训练集大小，占比: 181  (ratio = 0.834)
# --- 0.651219367980957 seconds ---
# 修剪模型：
# Test scores: maes=6.294, rmse=8.367, r2=0.852
# Val scores: maes=2.299, rmse=2.885, r2=0.947
# --- 0.6770451068878174 seconds ---
# ================================
# Iteration 7:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 42 (ratio = 0.194)
# 本次循环中新训练集大小，占比: 175  (ratio = 0.806)
# --- 0.4190666675567627 seconds ---
# 修剪模型：
# Test scores: maes=6.199, rmse=8.277, r2=0.855
# Val scores: maes=2.623, rmse=3.391, r2=0.930
# --- 0.6618924140930176 seconds ---
# ================================
# Iteration 8:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 44 (ratio = 0.203)
# 本次循环中新训练集大小，占比: 173  (ratio = 0.797)
# --- 0.42279934883117676 seconds ---
# 修剪模型：
# Test scores: maes=5.855, rmse=8.016, r2=0.864
# Val scores: maes=2.694, rmse=3.328, r2=0.933
# --- 0.7347931861877441 seconds ---
# ================================
# Iteration 9:
# 丢弃训练词条数量 : 3
# 本次循环中 old_val 数量: 46 (ratio = 0.212)
# 本次循环中新训练集大小，占比: 171  (ratio = 0.788)
# --- 0.4302680492401123 seconds ---
# 修剪模型：
# Test scores: maes=6.191, rmse=8.262, r2=0.856
# Val scores: maes=2.291, rmse=2.842, r2=0.952
# --- 0.6890716552734375 seconds ---
# ================================
# Iteration 10:
# 丢弃训练词条数量 : 7
# 本次循环中 old_val 数量: 49 (ratio = 0.226)
# 本次循环中新训练集大小，占比: 168  (ratio = 0.774)
# --- 0.41040706634521484 seconds ---
# 修剪模型：
# Test scores: maes=5.883, rmse=7.796, r2=0.872
# Val scores: maes=2.300, rmse=2.894, r2=0.949
# --- 0.625603199005127 seconds ---
# ================================
# Iteration 11:
# 丢弃训练词条数量 : 4
# 本次循环中 old_val 数量: 56 (ratio = 0.258)
# 本次循环中新训练集大小，占比: 161  (ratio = 0.742)
# --- 0.44643640518188477 seconds ---
# 修剪模型：
# Test scores: maes=6.132, rmse=8.201, r2=0.858
# Val scores: maes=2.164, rmse=2.658, r2=0.962
# --- 0.678476095199585 seconds ---
# ================================
# Iteration 12:
# 丢弃训练词条数量 : 3
# 本次循环中 old_val 数量: 60 (ratio = 0.276)
# 本次循环中新训练集大小，占比: 157  (ratio = 0.724)
# --- 0.42798900604248047 seconds ---
# 修剪模型：
# Test scores: maes=6.379, rmse=8.662, r2=0.841
# Val scores: maes=2.613, rmse=3.150, r2=0.950
# --- 0.43395018577575684 seconds ---
# ================================
# Iteration 13:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 63 (ratio = 0.290)
# 本次循环中新训练集大小，占比: 154  (ratio = 0.710)
# --- 0.40872669219970703 seconds ---
# 修剪模型：
# Test scores: maes=6.547, rmse=8.682, r2=0.841
# Val scores: maes=2.807, rmse=3.416, r2=0.938
# --- 0.4249403476715088 seconds ---
# ================================
# Iteration 14:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 65 (ratio = 0.300)
# 本次循环中新训练集大小，占比: 152  (ratio = 0.700)
# --- 0.4041907787322998 seconds ---
# 修剪模型：
# Test scores: maes=6.440, rmse=8.415, r2=0.850
# Val scores: maes=2.833, rmse=3.530, r2=0.934
# --- 0.41452908515930176 seconds ---
# ================================
# Iteration 15:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 67 (ratio = 0.309)
# 本次循环中新训练集大小，占比: 150  (ratio = 0.691)
# --- 0.40001416206359863 seconds ---
# 修剪模型：
# Test scores: maes=6.740, rmse=9.025, r2=0.828
# Val scores: maes=3.024, rmse=3.593, r2=0.930
# --- 0.4051187038421631 seconds ---
# ================================
# Iteration 16:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 69 (ratio = 0.318)
# 本次循环中新训练集大小，占比: 148  (ratio = 0.682)
# --- 0.4060332775115967 seconds ---
# 修剪模型：
# Test scores: maes=6.779, rmse=8.903, r2=0.832
# Val scores: maes=2.866, rmse=3.632, r2=0.933
# --- 0.408919095993042 seconds ---
# ================================
# Iteration 17:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 71 (ratio = 0.327)
# 本次循环中新训练集大小，占比: 146  (ratio = 0.673)
# --- 0.40441250801086426 seconds ---
# 修剪模型：
# Test scores: maes=6.742, rmse=8.766, r2=0.838
# Val scores: maes=2.642, rmse=3.316, r2=0.944
# --- 0.4147021770477295 seconds ---
# ================================
# Iteration 18:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 73 (ratio = 0.336)
# 本次循环中新训练集大小，占比: 144  (ratio = 0.664)
# --- 0.4107813835144043 seconds ---
# 修剪模型：
# Test scores: maes=6.775, rmse=8.540, r2=0.846
# Val scores: maes=2.708, rmse=3.464, r2=0.946
# --- 0.4095125198364258 seconds ---
# ================================
# Iteration 19:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 75 (ratio = 0.346)
# 本次循环中新训练集大小，占比: 142  (ratio = 0.654)
# --- 0.4069538116455078 seconds ---
# 修剪模型：
# Test scores: maes=6.846, rmse=8.594, r2=0.844
# Val scores: maes=2.634, rmse=3.325, r2=0.953
# --- 0.4131176471710205 seconds ---
# ================================
# Iteration 20:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 77 (ratio = 0.355)
# 本次循环中新训练集大小，占比: 140  (ratio = 0.645)
# --- 0.4003298282623291 seconds ---
# 修剪模型：
# Test scores: maes=6.595, rmse=8.712, r2=0.840
# Val scores: maes=2.835, rmse=3.488, r2=0.947
# --- 0.4049193859100342 seconds ---
# ================================
# Iteration 21:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 79 (ratio = 0.364)
# 本次循环中新训练集大小，占比: 138  (ratio = 0.636)
# --- 0.4035828113555908 seconds ---
# 修剪模型：
# Test scores: maes=6.961, rmse=8.845, r2=0.835
# Val scores: maes=2.568, rmse=3.335, r2=0.952
# --- 0.40249109268188477 seconds ---
# ================================
# Iteration 22:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 81 (ratio = 0.373)
# 本次循环中新训练集大小，占比: 136  (ratio = 0.627)
# --- 0.40824389457702637 seconds ---
# 修剪模型：
# Test scores: maes=6.744, rmse=8.638, r2=0.842
# Val scores: maes=2.659, rmse=3.217, r2=0.955
# --- 0.40080952644348145 seconds ---
# ================================
# Iteration 23:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 83 (ratio = 0.382)
# 本次循环中新训练集大小，占比: 134  (ratio = 0.618)
# --- 0.39914512634277344 seconds ---
# 修剪模型：
# Test scores: maes=7.226, rmse=8.986, r2=0.829
# Val scores: maes=2.976, rmse=3.810, r2=0.935
# --- 0.40839099884033203 seconds ---
# ================================
# Iteration 24:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 85 (ratio = 0.392)
# 本次循环中新训练集大小，占比: 132  (ratio = 0.608)
# --- 0.404524564743042 seconds ---
# 修剪模型：
# Test scores: maes=7.172, rmse=8.867, r2=0.834
# Val scores: maes=2.900, rmse=3.719, r2=0.940
# --- 0.40538859367370605 seconds ---
# ================================
# Iteration 25:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 87 (ratio = 0.401)
# 本次循环中新训练集大小，占比: 130  (ratio = 0.599)
# --- 0.40886402130126953 seconds ---
# 修剪模型：
# Test scores: maes=7.257, rmse=8.778, r2=0.837
# Val scores: maes=3.245, rmse=4.131, r2=0.924
# --- 0.40128588676452637 seconds ---
# ================================
# Iteration 26:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 89 (ratio = 0.410)
# 本次循环中新训练集大小，占比: 128  (ratio = 0.590)
# --- 0.40358996391296387 seconds ---
# 修剪模型：
# Test scores: maes=6.962, rmse=8.885, r2=0.833
# Val scores: maes=3.065, rmse=3.906, r2=0.933
# --- 0.3983585834503174 seconds ---
# ================================
# Iteration 27:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 91 (ratio = 0.419)
# 本次循环中新训练集大小，占比: 126  (ratio = 0.581)
# --- 0.4047534465789795 seconds ---
# 修剪模型：
# Test scores: maes=7.081, rmse=8.589, r2=0.844
# Val scores: maes=3.391, rmse=4.233, r2=0.920
# --- 0.4021282196044922 seconds ---
# ================================
# Iteration 28:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 93 (ratio = 0.429)
# 本次循环中新训练集大小，占比: 124  (ratio = 0.571)
# --- 0.3983879089355469 seconds ---
# 修剪模型：
# Test scores: maes=7.009, rmse=8.705, r2=0.840
# Val scores: maes=3.288, rmse=4.099, r2=0.927
# --- 0.40902066230773926 seconds ---
# ================================
# Iteration 29:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 95 (ratio = 0.438)
# 本次循环中新训练集大小，占比: 122  (ratio = 0.562)
# --- 0.4009106159210205 seconds ---
# 修剪模型：
# Test scores: maes=7.053, rmse=8.967, r2=0.830
# Val scores: maes=3.219, rmse=4.154, r2=0.926
# --- 0.40853238105773926 seconds ---
# ================================
# Iteration 30:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 97 (ratio = 0.447)
# 本次循环中新训练集大小，占比: 120  (ratio = 0.553)
# --- 0.40161800384521484 seconds ---
# 修剪模型：
# Test scores: maes=7.427, rmse=9.355, r2=0.815
# Val scores: maes=3.612, rmse=4.496, r2=0.915
# --- 0.40648555755615234 seconds ---
# ================================
# Iteration 31:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 99 (ratio = 0.456)
# 本次循环中新训练集大小，占比: 118  (ratio = 0.544)
# --- 0.4006526470184326 seconds ---
# 修剪模型：
# Test scores: maes=7.253, rmse=9.367, r2=0.815
# Val scores: maes=3.397, rmse=4.265, r2=0.923
# --- 0.40404558181762695 seconds ---
# ================================
# Iteration 32:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 101 (ratio = 0.465)
# 本次循环中新训练集大小，占比: 116  (ratio = 0.535)
# --- 0.40067076683044434 seconds ---
# 修剪模型：
# Test scores: maes=7.652, rmse=9.568, r2=0.807
# Val scores: maes=3.483, rmse=4.474, r2=0.915
# --- 0.39760518074035645 seconds ---
# ================================
# Iteration 33:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 103 (ratio = 0.475)
# 本次循环中新训练集大小，占比: 114  (ratio = 0.525)
# --- 0.3998847007751465 seconds ---
# 修剪模型：
# Test scores: maes=7.058, rmse=9.186, r2=0.822
# Val scores: maes=3.695, rmse=4.808, r2=0.900
# --- 0.4006690979003906 seconds ---
# ================================
# Iteration 34:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 105 (ratio = 0.484)
# 本次循环中新训练集大小，占比: 112  (ratio = 0.516)
# --- 0.392148494720459 seconds ---
# 修剪模型：
# Test scores: maes=7.246, rmse=9.387, r2=0.814
# Val scores: maes=3.925, rmse=4.909, r2=0.897
# --- 0.4013493061065674 seconds ---
# ================================
# Iteration 35:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 107 (ratio = 0.493)
# 本次循环中新训练集大小，占比: 110  (ratio = 0.507)
# --- 0.3886532783508301 seconds ---
# 修剪模型：
# Test scores: maes=7.003, rmse=8.927, r2=0.832
# Val scores: maes=3.886, rmse=4.958, r2=0.894
# --- 0.3999052047729492 seconds ---
# ================================
# Iteration 36:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 109 (ratio = 0.502)
# 本次循环中新训练集大小，占比: 108  (ratio = 0.498)
# --- 0.3980522155761719 seconds ---
# 修剪模型：
# Test scores: maes=6.779, rmse=8.995, r2=0.829
# Val scores: maes=4.118, rmse=5.205, r2=0.884
# --- 0.39808106422424316 seconds ---
# ================================
# Iteration 37:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 111 (ratio = 0.512)
# 本次循环中新训练集大小，占比: 106  (ratio = 0.488)
# --- 0.40696191787719727 seconds ---
# 修剪模型：
# Test scores: maes=6.933, rmse=8.888, r2=0.833
# Val scores: maes=4.117, rmse=5.147, r2=0.886
# --- 0.4035508632659912 seconds ---
# ================================
# Iteration 38:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 113 (ratio = 0.521)
# 本次循环中新训练集大小，占比: 104  (ratio = 0.479)
# --- 0.39956021308898926 seconds ---
# 修剪模型：
# Test scores: maes=6.994, rmse=9.145, r2=0.823
# Val scores: maes=3.976, rmse=4.854, r2=0.905
# --- 0.40161609649658203 seconds ---
# ================================
# Iteration 39:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 115 (ratio = 0.530)
# 本次循环中新训练集大小，占比: 102  (ratio = 0.470)
# --- 0.3905766010284424 seconds ---
# 修剪模型：
# Test scores: maes=7.545, rmse=9.608, r2=0.805
# Val scores: maes=4.074, rmse=5.054, r2=0.902
# --- 0.4143965244293213 seconds ---
# ================================
# Iteration 40:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 117 (ratio = 0.539)
# 本次循环中新训练集大小，占比: 100  (ratio = 0.461)
# --- 0.49065136909484863 seconds ---
# 修剪模型：
# Test scores: maes=7.343, rmse=9.469, r2=0.811
# Val scores: maes=4.253, rmse=5.271, r2=0.893
# --- 0.40990424156188965 seconds ---
# ================================
# Iteration 41:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 119 (ratio = 0.548)
# 本次循环中新训练集大小，占比: 98  (ratio = 0.452)
# --- 0.49432873725891113 seconds ---
# 修剪模型：
# Test scores: maes=8.071, rmse=10.175, r2=0.781
# Val scores: maes=4.197, rmse=5.256, r2=0.894
# --- 0.39287734031677246 seconds ---
# ================================
# Iteration 42:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 121 (ratio = 0.558)
# 本次循环中新训练集大小，占比: 96  (ratio = 0.442)
# --- 0.5090136528015137 seconds ---
# 修剪模型：
# Test scores: maes=8.540, rmse=10.795, r2=0.754
# Val scores: maes=4.717, rmse=5.833, r2=0.867
# --- 0.3941776752471924 seconds ---
# ================================
# Iteration 43:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 123 (ratio = 0.567)
# 本次循环中新训练集大小，占比: 94  (ratio = 0.433)
# --- 0.5117144584655762 seconds ---
# 修剪模型：
# Test scores: maes=8.776, rmse=10.838, r2=0.752
# Val scores: maes=4.904, rmse=6.156, r2=0.850
# --- 0.3905467987060547 seconds ---
# ================================
# Iteration 44:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 125 (ratio = 0.576)
# 本次循环中新训练集大小，占比: 92  (ratio = 0.424)
# --- 0.49723291397094727 seconds ---
# 修剪模型：
# Test scores: maes=8.349, rmse=10.732, r2=0.757
# Val scores: maes=4.863, rmse=6.016, r2=0.855
# --- 0.38722920417785645 seconds ---
# ================================
# Iteration 45:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 127 (ratio = 0.585)
# 本次循环中新训练集大小，占比: 90  (ratio = 0.415)
# --- 0.4918498992919922 seconds ---
# 修剪模型：
# Test scores: maes=8.816, rmse=10.841, r2=0.752
# Val scores: maes=4.779, rmse=5.951, r2=0.858
# --- 0.535632848739624 seconds ---
# ================================
# Iteration 46:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 129 (ratio = 0.594)
# 本次循环中新训练集大小，占比: 88  (ratio = 0.406)
# --- 0.48867249488830566 seconds ---
# 修剪模型：
# Test scores: maes=8.719, rmse=11.154, r2=0.737
# Val scores: maes=4.869, rmse=6.023, r2=0.854
# --- 0.5049118995666504 seconds ---
# ================================
# Iteration 47:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 131 (ratio = 0.604)
# 本次循环中新训练集大小，占比: 86  (ratio = 0.396)
# --- 0.4916841983795166 seconds ---
# 修剪模型：
# Test scores: maes=8.829, rmse=11.070, r2=0.741
# Val scores: maes=4.948, rmse=6.197, r2=0.845
# --- 0.48614954948425293 seconds ---
# ================================
# Iteration 48:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 133 (ratio = 0.613)
# 本次循环中新训练集大小，占比: 84  (ratio = 0.387)
# --- 0.48973774909973145 seconds ---
# 修剪模型：
# Test scores: maes=8.452, rmse=10.981, r2=0.745
# Val scores: maes=5.164, rmse=6.352, r2=0.834
# --- 0.49318480491638184 seconds ---
# ================================
# Iteration 49:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 135 (ratio = 0.622)
# 本次循环中新训练集大小，占比: 82  (ratio = 0.378)
# --- 0.48991894721984863 seconds ---
# 修剪模型：
# Test scores: maes=8.650, rmse=10.707, r2=0.758
# Val scores: maes=4.874, rmse=6.074, r2=0.849
# --- 0.5225217342376709 seconds ---
# ================================
# Iteration 50:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 137 (ratio = 0.631)
# 本次循环中新训练集大小，占比: 80  (ratio = 0.369)
# --- 0.5031013488769531 seconds ---
# 修剪模型：
# Test scores: maes=8.783, rmse=11.101, r2=0.740
# Val scores: maes=4.986, rmse=6.296, r2=0.836
# --- 0.48949384689331055 seconds ---
# ================================
# Iteration 51:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 139 (ratio = 0.641)
# 本次循环中新训练集大小，占比: 78  (ratio = 0.359)
# --- 0.48183155059814453 seconds ---
# 修剪模型：
# Test scores: maes=9.032, rmse=11.360, r2=0.727
# Val scores: maes=4.865, rmse=6.036, r2=0.847
# --- 0.48880696296691895 seconds ---
# ================================
# Iteration 52:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 141 (ratio = 0.650)
# 本次循环中新训练集大小，占比: 76  (ratio = 0.350)
# --- 0.4797184467315674 seconds ---
# 修剪模型：
# Test scores: maes=8.654, rmse=10.841, r2=0.752
# Val scores: maes=4.938, rmse=6.106, r2=0.842
# --- 0.4810669422149658 seconds ---
# ================================
# Iteration 53:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 143 (ratio = 0.659)
# 本次循环中新训练集大小，占比: 74  (ratio = 0.341)
# --- 0.4804496765136719 seconds ---
# 修剪模型：
# Test scores: maes=8.508, rmse=10.739, r2=0.756
# Val scores: maes=5.119, rmse=6.437, r2=0.822
# --- 0.48545145988464355 seconds ---
# ================================
# Iteration 54:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 145 (ratio = 0.668)
# 本次循环中新训练集大小，占比: 72  (ratio = 0.332)
# --- 0.47960329055786133 seconds ---
# 修剪模型：
# Test scores: maes=8.239, rmse=10.175, r2=0.781
# Val scores: maes=4.979, rmse=6.314, r2=0.829
# --- 0.4808204174041748 seconds ---
# ================================
# Iteration 55:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 147 (ratio = 0.677)
# 本次循环中新训练集大小，占比: 70  (ratio = 0.323)
# --- 0.48575592041015625 seconds ---
# 修剪模型：
# Test scores: maes=8.569, rmse=10.820, r2=0.753
# Val scores: maes=5.682, rmse=7.166, r2=0.779
# --- 0.476273775100708 seconds ---
# ================================
# Iteration 56:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 149 (ratio = 0.687)
# 本次循环中新训练集大小，占比: 68  (ratio = 0.313)
# --- 0.4739248752593994 seconds ---
# 修剪模型：
# Test scores: maes=8.897, rmse=11.098, r2=0.740
# Val scores: maes=5.772, rmse=7.317, r2=0.783
# --- 0.4880223274230957 seconds ---
# ================================
# Iteration 57:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 151 (ratio = 0.696)
# 本次循环中新训练集大小，占比: 66  (ratio = 0.304)
# --- 0.46977806091308594 seconds ---
# 修剪模型：
# Test scores: maes=9.492, rmse=12.104, r2=0.690
# Val scores: maes=5.987, rmse=7.729, r2=0.756
# --- 0.49524688720703125 seconds ---
# ================================
# Iteration 58:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 153 (ratio = 0.705)
# 本次循环中新训练集大小，占比: 64  (ratio = 0.295)
# --- 0.46181535720825195 seconds ---
# 修剪模型：
# Test scores: maes=9.905, rmse=12.441, r2=0.673
# Val scores: maes=6.255, rmse=7.905, r2=0.750
# --- 0.49278759956359863 seconds ---
# ================================
# Iteration 59:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 155 (ratio = 0.714)
# 本次循环中新训练集大小，占比: 62  (ratio = 0.286)
# --- 0.4557039737701416 seconds ---
# 修剪模型：
# Test scores: maes=10.171, rmse=12.687, r2=0.660
# Val scores: maes=6.562, rmse=8.144, r2=0.732
# --- 0.5115871429443359 seconds ---
# ================================
# Iteration 60:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 157 (ratio = 0.724)
# 本次循环中新训练集大小，占比: 60  (ratio = 0.276)
# --- 0.4590592384338379 seconds ---
# 修剪模型：
# Test scores: maes=9.400, rmse=11.752, r2=0.708
# Val scores: maes=6.404, rmse=8.055, r2=0.737
# --- 0.5046730041503906 seconds ---
# ================================
# Iteration 61:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 159 (ratio = 0.733)
# 本次循环中新训练集大小，占比: 58  (ratio = 0.267)
# --- 0.45848774909973145 seconds ---
# 修剪模型：
# Test scores: maes=8.634, rmse=11.163, r2=0.737
# Val scores: maes=7.063, rmse=8.766, r2=0.689
# --- 0.46955275535583496 seconds ---
# ================================
# Iteration 62:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 161 (ratio = 0.742)
# 本次循环中新训练集大小，占比: 56  (ratio = 0.258)
# --- 0.44797492027282715 seconds ---
# 修剪模型：
# Test scores: maes=9.738, rmse=12.466, r2=0.672
# Val scores: maes=7.657, rmse=9.496, r2=0.631
# --- 0.47394680976867676 seconds ---
# ================================
# Iteration 63:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 163 (ratio = 0.751)
# 本次循环中新训练集大小，占比: 54  (ratio = 0.249)
# --- 0.4460577964782715 seconds ---
# 修剪模型：
# Test scores: maes=10.237, rmse=12.861, r2=0.650
# Val scores: maes=8.116, rmse=9.997, r2=0.588
# --- 0.46384572982788086 seconds ---
# ================================
# Iteration 64:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 165 (ratio = 0.760)
# 本次循环中新训练集大小，占比: 52  (ratio = 0.240)
# --- 0.450211763381958 seconds ---
# 修剪模型：
# Test scores: maes=10.523, rmse=13.099, r2=0.637
# Val scores: maes=8.661, rmse=10.526, r2=0.539
# --- 0.46482348442077637 seconds ---
# ================================
# Iteration 65:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 167 (ratio = 0.770)
# 本次循环中新训练集大小，占比: 50  (ratio = 0.230)
# --- 0.4547722339630127 seconds ---
# 修剪模型：
# Test scores: maes=10.899, rmse=13.524, r2=0.613
# Val scores: maes=8.225, rmse=10.038, r2=0.577
# --- 0.45305681228637695 seconds ---
# ================================
# Iteration 66:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 169 (ratio = 0.779)
# 本次循环中新训练集大小，占比: 48  (ratio = 0.221)
# --- 0.46854186058044434 seconds ---
# 修剪模型：
# Test scores: maes=10.037, rmse=12.592, r2=0.665
# Val scores: maes=8.461, rmse=10.297, r2=0.554
# --- 0.5009291172027588 seconds ---
# ================================
# Iteration 67:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 171 (ratio = 0.788)
# 本次循环中新训练集大小，占比: 46  (ratio = 0.212)
# --- 0.4810318946838379 seconds ---
# 修剪模型：
# Test scores: maes=9.793, rmse=12.415, r2=0.674
# Val scores: maes=7.965, rmse=9.907, r2=0.588
# --- 0.5082275867462158 seconds ---
# ================================
# Iteration 68:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 173 (ratio = 0.797)
# 本次循环中新训练集大小，占比: 44  (ratio = 0.203)
# --- 0.44469785690307617 seconds ---
# 修剪模型：
# Test scores: maes=10.171, rmse=13.118, r2=0.636
# Val scores: maes=8.058, rmse=9.943, r2=0.581
# --- 0.5004820823669434 seconds ---
# ================================
# Iteration 69:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 175 (ratio = 0.806)
# 本次循环中新训练集大小，占比: 42  (ratio = 0.194)
# --- 0.4262816905975342 seconds ---
# 修剪模型：
# Test scores: maes=11.240, rmse=14.125, r2=0.578
# Val scores: maes=9.716, rmse=11.819, r2=0.406
# --- 0.44761228561401367 seconds ---
# ================================
# Iteration 70:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 177 (ratio = 0.816)
# 本次循环中新训练集大小，占比: 40  (ratio = 0.184)
# --- 0.4121427536010742 seconds ---
# 修剪模型：
# Test scores: maes=11.276, rmse=14.679, r2=0.545
# Val scores: maes=9.044, rmse=11.340, r2=0.461
# --- 0.44591474533081055 seconds ---
# ================================
# Iteration 71:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 179 (ratio = 0.825)
# 本次循环中新训练集大小，占比: 38  (ratio = 0.175)
# --- 0.40784263610839844 seconds ---
# 修剪模型：
# Test scores: maes=11.423, rmse=15.084, r2=0.519
# Val scores: maes=9.510, rmse=12.098, r2=0.396
# --- 0.4001455307006836 seconds ---
# ================================
# Iteration 72:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 181 (ratio = 0.834)
# 本次循环中新训练集大小，占比: 36  (ratio = 0.166)
# --- 0.42264676094055176 seconds ---
# 修剪模型：
# Test scores: maes=11.464, rmse=14.938, r2=0.528
# Val scores: maes=10.667, rmse=13.043, r2=0.303
# --- 0.4022665023803711 seconds ---
# ================================
# Iteration 73:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 183 (ratio = 0.843)
# 本次循环中新训练集大小，占比: 34  (ratio = 0.157)
# --- 0.40869617462158203 seconds ---
# 修剪模型：
# Test scores: maes=11.418, rmse=15.046, r2=0.522
# Val scores: maes=10.634, rmse=13.091, r2=0.300
# --- 0.41475510597229004 seconds ---
# ================================
# Iteration 74:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 185 (ratio = 0.853)
# 本次循环中新训练集大小，占比: 32  (ratio = 0.147)
# --- 0.4187796115875244 seconds ---
# 修剪模型：
# Test scores: maes=12.697, rmse=16.482, r2=0.426
# Val scores: maes=10.524, rmse=13.037, r2=0.305
# --- 0.4173715114593506 seconds ---
# ================================
# Iteration 75:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 187 (ratio = 0.862)
# 本次循环中新训练集大小，占比: 30  (ratio = 0.138)
# --- 0.4172217845916748 seconds ---
# 修剪模型：
# Test scores: maes=11.788, rmse=15.322, r2=0.504
# Val scores: maes=10.403, rmse=12.777, r2=0.334
# --- 0.41481709480285645 seconds ---
# ================================
# Iteration 76:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 189 (ratio = 0.871)
# 本次循环中新训练集大小，占比: 28  (ratio = 0.129)
# --- 0.4219796657562256 seconds ---
# 修剪模型：
# Test scores: maes=11.899, rmse=15.681, r2=0.480
# Val scores: maes=10.543, rmse=12.991, r2=0.328
# --- 0.4112582206726074 seconds ---
# ================================
# Iteration 77:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 191 (ratio = 0.880)
# 本次循环中新训练集大小，占比: 26  (ratio = 0.120)
# --- 0.4132044315338135 seconds ---
# 修剪模型：
# Test scores: maes=13.121, rmse=16.680, r2=0.412
# Val scores: maes=10.274, rmse=13.030, r2=0.319
# --- 0.4062361717224121 seconds ---
# ================================
# Iteration 78:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 193 (ratio = 0.889)
# 本次循环中新训练集大小，占比: 24  (ratio = 0.111)
# --- 0.4045891761779785 seconds ---
# 修剪模型：
# Test scores: maes=15.827, rmse=19.119, r2=0.227
# Val scores: maes=11.998, rmse=14.721, r2=0.159
# --- 0.42489147186279297 seconds ---
# ================================
# Iteration 79:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 195 (ratio = 0.899)
# 本次循环中新训练集大小，占比: 22  (ratio = 0.101)
# --- 0.39910221099853516 seconds ---
# 修剪模型：
# Test scores: maes=13.429, rmse=16.911, r2=0.396
# Val scores: maes=12.226, rmse=14.886, r2=0.170
# --- 0.4218759536743164 seconds ---

# %%
size_old_val_b, ids_b, test_scores_b, val_scores_b,test_fit_b,remove_b = prune_rd(
    model[b], X_train_val, y_train_val, X_test, y_test,max_iter=80,min_drop= 2,threshold=maes_b / 2,train_size= 0.9, file_out=file_out_b)
# Out:
# ================================
# Iteration 0:
# 丢弃训练词条数量 : 11
# 本次循环中 old_val 数量: 0 (ratio = 0.000)
# 本次循环中新训练集大小，占比: 217  (ratio = 1.000)
# --- 0.10717606544494629 seconds ---
# 修剪模型：
# Test scores: maes=6.509, rmse=8.664, r2=0.841
# --- 0.09283089637756348 seconds ---
# ================================
# Iteration 1:
# 丢弃训练词条数量 : 5
# 本次循环中 old_val 数量: 11 (ratio = 0.051)
# 本次循环中新训练集大小，占比: 206  (ratio = 0.949)
# --- 0.09478378295898438 seconds ---
# 修剪模型：
# Test scores: maes=7.358, rmse=9.439, r2=0.812
# Val scores: maes=2.600, rmse=3.452, r2=0.934
# --- 0.09820795059204102 seconds ---
# ================================
# Iteration 2:
# 丢弃训练词条数量 : 5
# 本次循环中 old_val 数量: 16 (ratio = 0.074)
# 本次循环中新训练集大小，占比: 201  (ratio = 0.926)
# --- 0.0911860466003418 seconds ---
# 修剪模型：
# Test scores: maes=6.580, rmse=8.528, r2=0.846
# Val scores: maes=2.898, rmse=3.771, r2=0.894
# --- 0.09350323677062988 seconds ---
# ================================
# Iteration 3:
# 丢弃训练词条数量 : 5
# 本次循环中 old_val 数量: 21 (ratio = 0.097)
# 本次循环中新训练集大小，占比: 196  (ratio = 0.903)
# --- 0.08965206146240234 seconds ---
# 修剪模型：
# Test scores: maes=6.940, rmse=8.985, r2=0.829
# Val scores: maes=2.087, rmse=2.571, r2=0.940
# --- 0.09257698059082031 seconds ---
# ================================
# Iteration 4:
# 丢弃训练词条数量 : 6
# 本次循环中 old_val 数量: 26 (ratio = 0.120)
# 本次循环中新训练集大小，占比: 191  (ratio = 0.880)
# --- 0.0908355712890625 seconds ---
# 修剪模型：
# Test scores: maes=6.556, rmse=8.589, r2=0.844
# Val scores: maes=2.548, rmse=3.303, r2=0.896
# --- 0.09383964538574219 seconds ---
# ================================
# Iteration 5:
# 丢弃训练词条数量 : 4
# 本次循环中 old_val 数量: 32 (ratio = 0.147)
# 本次循环中新训练集大小，占比: 185  (ratio = 0.853)
# --- 0.09806013107299805 seconds ---
# 修剪模型：
# Test scores: maes=6.695, rmse=8.870, r2=0.834
# Val scores: maes=2.888, rmse=3.634, r2=0.898
# --- 0.10714459419250488 seconds ---
# ================================
# Iteration 6:
# 丢弃训练词条数量 : 6
# 本次循环中 old_val 数量: 36 (ratio = 0.166)
# 本次循环中新训练集大小，占比: 181  (ratio = 0.834)
# --- 0.09022808074951172 seconds ---
# 修剪模型：
# Test scores: maes=7.287, rmse=9.438, r2=0.812
# Val scores: maes=2.796, rmse=3.538, r2=0.918
# --- 0.09008216857910156 seconds ---
# ================================
# Iteration 7:
# 丢弃训练词条数量 : 7
# 本次循环中 old_val 数量: 42 (ratio = 0.194)
# 本次循环中新训练集大小，占比: 175  (ratio = 0.806)
# --- 0.08756709098815918 seconds ---
# 修剪模型：
# Test scores: maes=6.755, rmse=8.521, r2=0.847
# Val scores: maes=2.583, rmse=3.304, r2=0.927
# --- 0.09396219253540039 seconds ---
# ================================
# Iteration 8:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 49 (ratio = 0.226)
# 本次循环中新训练集大小，占比: 168  (ratio = 0.774)
# --- 0.0855562686920166 seconds ---
# 修剪模型：
# Test scores: maes=6.780, rmse=8.856, r2=0.834
# Val scores: maes=2.842, rmse=3.707, r2=0.916
# --- 0.09337663650512695 seconds ---
# ================================
# Iteration 9:
# 丢弃训练词条数量 : 3
# 本次循环中 old_val 数量: 51 (ratio = 0.235)
# 本次循环中新训练集大小，占比: 166  (ratio = 0.765)
# --- 0.0926504135131836 seconds ---
# 修剪模型：
# Test scores: maes=7.510, rmse=9.359, r2=0.815
# Val scores: maes=3.082, rmse=3.695, r2=0.924
# --- 0.09032082557678223 seconds ---
# ================================
# Iteration 10:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 54 (ratio = 0.249)
# 本次循环中新训练集大小，占比: 163  (ratio = 0.751)
# --- 0.08804607391357422 seconds ---
# 修剪模型：
# Test scores: maes=6.727, rmse=8.366, r2=0.852
# Val scores: maes=3.000, rmse=3.956, r2=0.910
# --- 0.10069513320922852 seconds ---
# ================================
# Iteration 11:
# 丢弃训练词条数量 : 3
# 本次循环中 old_val 数量: 56 (ratio = 0.258)
# 本次循环中新训练集大小，占比: 161  (ratio = 0.742)
# --- 0.09497261047363281 seconds ---
# 修剪模型：
# Test scores: maes=6.585, rmse=8.552, r2=0.845
# Val scores: maes=3.079, rmse=3.920, r2=0.912
# --- 0.0909125804901123 seconds ---
# ================================
# Iteration 12:
# 丢弃训练词条数量 : 3
# 本次循环中 old_val 数量: 59 (ratio = 0.272)
# 本次循环中新训练集大小，占比: 158  (ratio = 0.728)
# --- 0.08616781234741211 seconds ---
# 修剪模型：
# Test scores: maes=6.926, rmse=8.674, r2=0.841
# Val scores: maes=3.071, rmse=3.920, r2=0.908
# --- 0.08722591400146484 seconds ---
# ================================
# Iteration 13:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 62 (ratio = 0.286)
# 本次循环中新训练集大小，占比: 155  (ratio = 0.714)
# --- 0.08890604972839355 seconds ---
# 修剪模型：
# Test scores: maes=6.818, rmse=9.061, r2=0.826
# Val scores: maes=3.422, rmse=4.384, r2=0.890
# --- 0.08736515045166016 seconds ---
# ================================
# Iteration 14:
# 丢弃训练词条数量 : 3
# 本次循环中 old_val 数量: 64 (ratio = 0.295)
# 本次循环中新训练集大小，占比: 153  (ratio = 0.705)
# --- 0.08616018295288086 seconds ---
# 修剪模型：
# Test scores: maes=6.875, rmse=8.289, r2=0.855
# Val scores: maes=3.041, rmse=3.676, r2=0.937
# --- 0.09325456619262695 seconds ---
# ================================
# Iteration 15:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 67 (ratio = 0.309)
# 本次循环中新训练集大小，占比: 150  (ratio = 0.691)
# --- 0.09434676170349121 seconds ---
# 修剪模型：
# Test scores: maes=6.579, rmse=8.384, r2=0.851
# Val scores: maes=2.796, rmse=3.671, r2=0.936
# --- 0.0886528491973877 seconds ---
# ================================
# Iteration 16:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 69 (ratio = 0.318)
# 本次循环中新训练集大小，占比: 148  (ratio = 0.682)
# --- 0.09671831130981445 seconds ---
# 修剪模型：
# Test scores: maes=6.432, rmse=8.297, r2=0.855
# Val scores: maes=3.414, rmse=4.165, r2=0.916
# --- 0.11908984184265137 seconds ---
# ================================
# Iteration 17:
# 丢弃训练词条数量 : 3
# 本次循环中 old_val 数量: 71 (ratio = 0.327)
# 本次循环中新训练集大小，占比: 146  (ratio = 0.673)
# --- 0.09698748588562012 seconds ---
# 修剪模型：
# Test scores: maes=6.457, rmse=8.855, r2=0.834
# Val scores: maes=3.653, rmse=4.573, r2=0.902
# --- 0.09048676490783691 seconds ---
# ================================
# Iteration 18:
# 丢弃训练词条数量 : 3
# 本次循环中 old_val 数量: 74 (ratio = 0.341)
# 本次循环中新训练集大小，占比: 143  (ratio = 0.659)
# --- 0.08573079109191895 seconds ---
# 修剪模型：
# Test scores: maes=7.228, rmse=8.861, r2=0.834
# Val scores: maes=3.309, rmse=4.202, r2=0.928
# --- 0.09070682525634766 seconds ---
# ================================
# Iteration 19:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 77 (ratio = 0.355)
# 本次循环中新训练集大小，占比: 140  (ratio = 0.645)
# --- 0.08500027656555176 seconds ---
# 修剪模型：
# Test scores: maes=6.746, rmse=8.616, r2=0.843
# Val scores: maes=3.296, rmse=4.225, r2=0.925
# --- 0.08874654769897461 seconds ---
# ================================
# Iteration 20:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 79 (ratio = 0.364)
# 本次循环中新训练集大小，占比: 138  (ratio = 0.636)
# --- 0.08804655075073242 seconds ---
# 修剪模型：
# Test scores: maes=7.092, rmse=9.128, r2=0.824
# Val scores: maes=3.371, rmse=4.212, r2=0.925
# --- 0.0976109504699707 seconds ---
# ================================
# Iteration 21:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 81 (ratio = 0.373)
# 本次循环中新训练集大小，占比: 136  (ratio = 0.627)
# --- 0.09004831314086914 seconds ---
# 修剪模型：
# Test scores: maes=7.474, rmse=9.258, r2=0.819
# Val scores: maes=3.349, rmse=4.324, r2=0.920
# --- 0.09858012199401855 seconds ---
# ================================
# Iteration 22:
# 丢弃训练词条数量 : 3
# 本次循环中 old_val 数量: 83 (ratio = 0.382)
# 本次循环中新训练集大小，占比: 134  (ratio = 0.618)
# --- 0.09139847755432129 seconds ---
# 修剪模型：
# Test scores: maes=6.136, rmse=7.814, r2=0.871
# Val scores: maes=3.490, rmse=4.502, r2=0.913
# --- 0.08557701110839844 seconds ---
# ================================
# Iteration 23:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 86 (ratio = 0.396)
# 本次循环中新训练集大小，占比: 131  (ratio = 0.604)
# --- 0.08905696868896484 seconds ---
# 修剪模型：
# Test scores: maes=6.684, rmse=8.410, r2=0.851
# Val scores: maes=3.536, rmse=4.661, r2=0.910
# --- 0.08739542961120605 seconds ---
# ================================
# Iteration 24:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 88 (ratio = 0.406)
# 本次循环中新训练集大小，占比: 129  (ratio = 0.594)
# --- 0.08699989318847656 seconds ---
# 修剪模型：
# Test scores: maes=6.998, rmse=9.000, r2=0.829
# Val scores: maes=3.623, rmse=4.453, r2=0.916
# --- 0.08860063552856445 seconds ---
# ================================
# Iteration 25:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 90 (ratio = 0.415)
# 本次循环中新训练集大小，占比: 127  (ratio = 0.585)
# --- 0.08823513984680176 seconds ---
# 修剪模型：
# Test scores: maes=6.813, rmse=8.672, r2=0.841
# Val scores: maes=3.693, rmse=4.737, r2=0.904
# --- 0.08754301071166992 seconds ---
# ================================
# Iteration 26:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 92 (ratio = 0.424)
# 本次循环中新训练集大小，占比: 125  (ratio = 0.576)
# --- 0.09042477607727051 seconds ---
# 修剪模型：
# Test scores: maes=7.640, rmse=9.816, r2=0.796
# Val scores: maes=3.362, rmse=4.090, r2=0.928
# --- 0.08872818946838379 seconds ---
# ================================
# Iteration 27:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 94 (ratio = 0.433)
# 本次循环中新训练集大小，占比: 123  (ratio = 0.567)
# --- 0.09414148330688477 seconds ---
# 修剪模型：
# Test scores: maes=6.753, rmse=8.867, r2=0.834
# Val scores: maes=3.503, rmse=4.457, r2=0.914
# --- 0.09975099563598633 seconds ---
# ================================
# Iteration 28:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 96 (ratio = 0.442)
# 本次循环中新训练集大小，占比: 121  (ratio = 0.558)
# --- 0.0939023494720459 seconds ---
# 修剪模型：
# Test scores: maes=6.594, rmse=8.500, r2=0.847
# Val scores: maes=3.811, rmse=4.736, r2=0.903
# --- 0.08624625205993652 seconds ---
# ================================
# Iteration 29:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 98 (ratio = 0.452)
# 本次循环中新训练集大小，占比: 119  (ratio = 0.548)
# --- 0.0872659683227539 seconds ---
# 修剪模型：
# Test scores: maes=7.098, rmse=8.642, r2=0.842
# Val scores: maes=3.842, rmse=4.883, r2=0.895
# --- 0.08641910552978516 seconds ---
# ================================
# Iteration 30:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 100 (ratio = 0.461)
# 本次循环中新训练集大小，占比: 117  (ratio = 0.539)
# --- 0.08347034454345703 seconds ---
# 修剪模型：
# Test scores: maes=7.642, rmse=9.441, r2=0.812
# Val scores: maes=3.924, rmse=4.966, r2=0.891
# --- 0.08686280250549316 seconds ---
# ================================
# Iteration 31:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 102 (ratio = 0.470)
# 本次循环中新训练集大小，占比: 115  (ratio = 0.530)
# --- 0.08578109741210938 seconds ---
# 修剪模型：
# Test scores: maes=7.682, rmse=9.509, r2=0.809
# Val scores: maes=3.761, rmse=4.876, r2=0.899
# --- 0.09154081344604492 seconds ---
# ================================
# Iteration 32:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 104 (ratio = 0.479)
# 本次循环中新训练集大小，占比: 113  (ratio = 0.521)
# --- 0.0892634391784668 seconds ---
# 修剪模型：
# Test scores: maes=7.191, rmse=9.425, r2=0.812
# Val scores: maes=3.824, rmse=4.919, r2=0.896
# --- 0.10698771476745605 seconds ---
# ================================
# Iteration 33:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 106 (ratio = 0.488)
# 本次循环中新训练集大小，占比: 111  (ratio = 0.512)
# --- 0.09733176231384277 seconds ---
# 修剪模型：
# Test scores: maes=7.219, rmse=9.195, r2=0.821
# Val scores: maes=3.901, rmse=4.849, r2=0.900
# --- 0.09833002090454102 seconds ---
# ================================
# Iteration 34:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 108 (ratio = 0.498)
# 本次循环中新训练集大小，占比: 109  (ratio = 0.502)
# --- 0.09889626502990723 seconds ---
# 修剪模型：
# Test scores: maes=6.626, rmse=8.365, r2=0.852
# Val scores: maes=4.495, rmse=5.643, r2=0.865
# --- 0.09150528907775879 seconds ---
# ================================
# Iteration 35:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 110 (ratio = 0.507)
# 本次循环中新训练集大小，占比: 107  (ratio = 0.493)
# --- 0.09234309196472168 seconds ---
# 修剪模型：
# Test scores: maes=7.383, rmse=9.467, r2=0.811
# Val scores: maes=4.169, rmse=5.221, r2=0.885
# --- 0.08439087867736816 seconds ---
# ================================
# Iteration 36:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 112 (ratio = 0.516)
# 本次循环中新训练集大小，占比: 105  (ratio = 0.484)
# --- 0.08536720275878906 seconds ---
# 修剪模型：
# Test scores: maes=8.051, rmse=9.875, r2=0.794
# Val scores: maes=4.113, rmse=5.205, r2=0.884
# --- 0.10117316246032715 seconds ---
# ================================
# Iteration 37:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 114 (ratio = 0.525)
# 本次循环中新训练集大小，占比: 103  (ratio = 0.475)
# --- 0.10112118721008301 seconds ---
# 修剪模型：
# Test scores: maes=7.972, rmse=9.867, r2=0.794
# Val scores: maes=4.779, rmse=6.062, r2=0.844
# --- 0.11023592948913574 seconds ---
# ================================
# Iteration 38:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 116 (ratio = 0.535)
# 本次循环中新训练集大小，占比: 101  (ratio = 0.465)
# --- 0.1062474250793457 seconds ---
# 修剪模型：
# Test scores: maes=6.761, rmse=8.760, r2=0.838
# Val scores: maes=4.444, rmse=5.838, r2=0.853
# --- 0.0924673080444336 seconds ---
# ================================
# Iteration 39:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 118 (ratio = 0.544)
# 本次循环中新训练集大小，占比: 99  (ratio = 0.456)
# --- 0.09921813011169434 seconds ---
# 修剪模型：
# Test scores: maes=7.633, rmse=9.304, r2=0.817
# Val scores: maes=4.120, rmse=5.257, r2=0.879
# --- 0.09627199172973633 seconds ---
# ================================
# Iteration 40:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 120 (ratio = 0.553)
# 本次循环中新训练集大小，占比: 97  (ratio = 0.447)
# --- 0.08588790893554688 seconds ---
# 修剪模型：
# Test scores: maes=6.911, rmse=8.706, r2=0.840
# Val scores: maes=4.275, rmse=5.387, r2=0.872
# --- 0.08861160278320312 seconds ---
# ================================
# Iteration 41:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 122 (ratio = 0.562)
# 本次循环中新训练集大小，占比: 95  (ratio = 0.438)
# --- 0.09951400756835938 seconds ---
# 修剪模型：
# Test scores: maes=7.412, rmse=8.823, r2=0.835
# Val scores: maes=4.377, rmse=5.491, r2=0.875
# --- 0.0937347412109375 seconds ---
# ================================
# Iteration 42:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 124 (ratio = 0.571)
# 本次循环中新训练集大小，占比: 93  (ratio = 0.429)
# --- 0.08955836296081543 seconds ---
# 修剪模型：
# Test scores: maes=7.793, rmse=9.596, r2=0.805
# Val scores: maes=4.666, rmse=6.004, r2=0.850
# --- 0.09002900123596191 seconds ---
# ================================
# Iteration 43:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 126 (ratio = 0.581)
# 本次循环中新训练集大小，占比: 91  (ratio = 0.419)
# --- 0.10449695587158203 seconds ---
# 修剪模型：
# Test scores: maes=7.622, rmse=9.989, r2=0.789
# Val scores: maes=4.772, rmse=6.184, r2=0.845
# --- 0.08612251281738281 seconds ---
# ================================
# Iteration 44:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 128 (ratio = 0.590)
# 本次循环中新训练集大小，占比: 89  (ratio = 0.410)
# --- 0.08666062355041504 seconds ---
# 修剪模型：
# Test scores: maes=7.436, rmse=9.002, r2=0.829
# Val scores: maes=4.842, rmse=6.077, r2=0.851
# --- 0.08716917037963867 seconds ---
# ================================
# Iteration 45:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 130 (ratio = 0.599)
# 本次循环中新训练集大小，占比: 87  (ratio = 0.401)
# --- 0.09535098075866699 seconds ---
# 修剪模型：
# Test scores: maes=7.361, rmse=8.836, r2=0.835
# Val scores: maes=4.980, rmse=6.216, r2=0.848
# --- 0.08782529830932617 seconds ---
# ================================
# Iteration 46:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 132 (ratio = 0.608)
# 本次循环中新训练集大小，占比: 85  (ratio = 0.392)
# --- 0.08579254150390625 seconds ---
# 修剪模型：
# Test scores: maes=6.950, rmse=8.511, r2=0.847
# Val scores: maes=4.957, rmse=6.330, r2=0.844
# --- 0.08680582046508789 seconds ---
# ================================
# Iteration 47:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 134 (ratio = 0.618)
# 本次循环中新训练集大小，占比: 83  (ratio = 0.382)
# --- 0.09539461135864258 seconds ---
# 修剪模型：
# Test scores: maes=7.525, rmse=9.608, r2=0.805
# Val scores: maes=5.842, rmse=7.256, r2=0.792
# --- 0.10836601257324219 seconds ---
# ================================
# Iteration 48:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 136 (ratio = 0.627)
# 本次循环中新训练集大小，占比: 81  (ratio = 0.373)
# --- 0.10835075378417969 seconds ---
# 修剪模型：
# Test scores: maes=6.830, rmse=8.536, r2=0.846
# Val scores: maes=5.585, rmse=7.118, r2=0.797
# --- 0.09566617012023926 seconds ---
# ================================
# Iteration 49:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 138 (ratio = 0.636)
# 本次循环中新训练集大小，占比: 79  (ratio = 0.364)
# --- 0.09014558792114258 seconds ---
# 修剪模型：
# Test scores: maes=7.655, rmse=9.297, r2=0.817
# Val scores: maes=5.177, rmse=6.514, r2=0.830
# --- 0.09533834457397461 seconds ---
# ================================
# Iteration 50:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 140 (ratio = 0.645)
# 本次循环中新训练集大小，占比: 77  (ratio = 0.355)
# --- 0.08638858795166016 seconds ---
# 修剪模型：
# Test scores: maes=6.798, rmse=8.641, r2=0.842
# Val scores: maes=5.246, rmse=6.556, r2=0.826
# --- 0.09195518493652344 seconds ---
# ================================
# Iteration 51:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 142 (ratio = 0.654)
# 本次循环中新训练集大小，占比: 75  (ratio = 0.346)
# --- 0.08634734153747559 seconds ---
# 修剪模型：
# Test scores: maes=7.222, rmse=9.261, r2=0.819
# Val scores: maes=5.310, rmse=6.633, r2=0.820
# --- 0.08475923538208008 seconds ---
# ================================
# Iteration 52:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 144 (ratio = 0.664)
# 本次循环中新训练集大小，占比: 73  (ratio = 0.336)
# --- 0.08259963989257812 seconds ---
# 修剪模型：
# Test scores: maes=6.604, rmse=8.534, r2=0.846
# Val scores: maes=6.050, rmse=7.641, r2=0.762
# --- 0.09901118278503418 seconds ---
# ================================
# Iteration 53:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 146 (ratio = 0.673)
# 本次循环中新训练集大小，占比: 71  (ratio = 0.327)
# --- 0.10321903228759766 seconds ---
# 修剪模型：
# Test scores: maes=7.497, rmse=9.670, r2=0.802
# Val scores: maes=5.920, rmse=7.346, r2=0.787
# --- 0.10303759574890137 seconds ---
# ================================
# Iteration 54:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 148 (ratio = 0.682)
# 本次循环中新训练集大小，占比: 69  (ratio = 0.318)
# --- 0.09153509140014648 seconds ---
# 修剪模型：
# Test scores: maes=6.902, rmse=9.207, r2=0.821
# Val scores: maes=5.981, rmse=7.617, r2=0.768
# --- 0.08285093307495117 seconds ---
# ================================
# Iteration 55:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 150 (ratio = 0.691)
# 本次循环中新训练集大小，占比: 67  (ratio = 0.309)
# --- 0.08365893363952637 seconds ---
# 修剪模型：
# Test scores: maes=7.888, rmse=9.969, r2=0.790
# Val scores: maes=5.989, rmse=7.224, r2=0.796
# --- 0.08395600318908691 seconds ---
# ================================
# Iteration 56:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 152 (ratio = 0.700)
# 本次循环中新训练集大小，占比: 65  (ratio = 0.300)
# --- 0.0809473991394043 seconds ---
# 修剪模型：
# Test scores: maes=7.873, rmse=10.905, r2=0.749
# Val scores: maes=6.087, rmse=7.579, r2=0.776
# --- 0.09155011177062988 seconds ---
# ================================
# Iteration 57:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 154 (ratio = 0.710)
# 本次循环中新训练集大小，占比: 63  (ratio = 0.290)
# --- 0.08596420288085938 seconds ---
# 修剪模型：
# Test scores: maes=7.662, rmse=10.214, r2=0.780
# Val scores: maes=6.709, rmse=8.242, r2=0.735
# --- 0.09920406341552734 seconds ---
# ================================
# Iteration 58:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 156 (ratio = 0.719)
# 本次循环中新训练集大小，占比: 61  (ratio = 0.281)
# --- 0.08831930160522461 seconds ---
# 修剪模型：
# Test scores: maes=8.604, rmse=10.651, r2=0.760
# Val scores: maes=6.736, rmse=8.226, r2=0.734
# --- 0.0834646224975586 seconds ---
# ================================
# Iteration 59:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 158 (ratio = 0.728)
# 本次循环中新训练集大小，占比: 59  (ratio = 0.272)
# --- 0.09211134910583496 seconds ---
# 修剪模型：
# Test scores: maes=7.486, rmse=10.393, r2=0.772
# Val scores: maes=6.704, rmse=8.221, r2=0.732
# --- 0.09302568435668945 seconds ---
# ================================
# Iteration 60:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 160 (ratio = 0.737)
# 本次循环中新训练集大小，占比: 57  (ratio = 0.263)
# --- 0.0855720043182373 seconds ---
# 修剪模型：
# Test scores: maes=8.264, rmse=10.637, r2=0.761
# Val scores: maes=7.472, rmse=9.582, r2=0.634
# --- 0.08715510368347168 seconds ---
# ================================
# Iteration 61:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 162 (ratio = 0.747)
# 本次循环中新训练集大小，占比: 55  (ratio = 0.253)
# --- 0.086151123046875 seconds ---
# 修剪模型：
# Test scores: maes=10.057, rmse=12.376, r2=0.676
# Val scores: maes=7.971, rmse=10.025, r2=0.595
# --- 0.0858297348022461 seconds ---
# ================================
# Iteration 62:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 164 (ratio = 0.756)
# 本次循环中新训练集大小，占比: 53  (ratio = 0.244)
# --- 0.07987761497497559 seconds ---
# 修剪模型：
# Test scores: maes=9.270, rmse=11.490, r2=0.721
# Val scores: maes=7.713, rmse=9.542, r2=0.630
# --- 0.08909749984741211 seconds ---
# ================================
# Iteration 63:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 166 (ratio = 0.765)
# 本次循环中新训练集大小，占比: 51  (ratio = 0.235)
# --- 0.08166909217834473 seconds ---
# 修剪模型：
# Test scores: maes=10.913, rmse=13.774, r2=0.599
# Val scores: maes=8.101, rmse=10.250, r2=0.568
# --- 0.08047771453857422 seconds ---
# ================================
# Iteration 64:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 168 (ratio = 0.774)
# 本次循环中新训练集大小，占比: 49  (ratio = 0.226)
# --- 0.10018610954284668 seconds ---
# 修剪模型：
# Test scores: maes=10.712, rmse=13.258, r2=0.629
# Val scores: maes=8.328, rmse=10.628, r2=0.534
# --- 0.10566902160644531 seconds ---
# ================================
# Iteration 65:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 170 (ratio = 0.783)
# 本次循环中新训练集大小，占比: 47  (ratio = 0.217)
# --- 0.10411429405212402 seconds ---
# 修剪模型：
# Test scores: maes=11.283, rmse=13.406, r2=0.620
# Val scores: maes=8.668, rmse=10.645, r2=0.531
# --- 0.08347749710083008 seconds ---
# ================================
# Iteration 66:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 172 (ratio = 0.793)
# 本次循环中新训练集大小，占比: 45  (ratio = 0.207)
# --- 0.08833646774291992 seconds ---
# 修剪模型：
# Test scores: maes=12.466, rmse=15.028, r2=0.523
# Val scores: maes=8.764, rmse=11.019, r2=0.495
# --- 0.08981752395629883 seconds ---
# ================================
# Iteration 67:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 174 (ratio = 0.802)
# 本次循环中新训练集大小，占比: 43  (ratio = 0.198)
# --- 0.08731293678283691 seconds ---
# 修剪模型：
# Test scores: maes=12.457, rmse=15.288, r2=0.506
# Val scores: maes=8.799, rmse=11.468, r2=0.448
# --- 0.08152318000793457 seconds ---
# ================================
# Iteration 68:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 176 (ratio = 0.811)
# 本次循环中新训练集大小，占比: 41  (ratio = 0.189)
# --- 0.0834348201751709 seconds ---
# 修剪模型：
# Test scores: maes=12.287, rmse=14.714, r2=0.542
# Val scores: maes=7.990, rmse=10.343, r2=0.557
# --- 0.0961754322052002 seconds ---
# ================================
# Iteration 69:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 178 (ratio = 0.820)
# 本次循环中新训练集大小，占比: 39  (ratio = 0.180)
# --- 0.07893943786621094 seconds ---
# 修剪模型：
# Test scores: maes=13.957, rmse=17.098, r2=0.382
# Val scores: maes=9.508, rmse=12.276, r2=0.403
# --- 0.08626627922058105 seconds ---
# ================================
# Iteration 70:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 180 (ratio = 0.829)
# 本次循环中新训练集大小，占比: 37  (ratio = 0.171)
# --- 0.08564877510070801 seconds ---
# 修剪模型：
# Test scores: maes=14.402, rmse=17.675, r2=0.340
# Val scores: maes=10.278, rmse=13.089, r2=0.331
# --- 0.09258747100830078 seconds ---
# ================================
# Iteration 71:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 182 (ratio = 0.839)
# 本次循环中新训练集大小，占比: 35  (ratio = 0.161)
# --- 0.10248517990112305 seconds ---
# 修剪模型：
# Test scores: maes=15.199, rmse=18.154, r2=0.304
# Val scores: maes=9.441, rmse=12.307, r2=0.414
# --- 0.08718109130859375 seconds ---
# ================================
# Iteration 72:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 184 (ratio = 0.848)
# 本次循环中新训练集大小，占比: 33  (ratio = 0.152)
# --- 0.09126591682434082 seconds ---
# 修剪模型：
# Test scores: maes=13.292, rmse=16.302, r2=0.438
# Val scores: maes=9.550, rmse=12.351, r2=0.415
# --- 0.08765196800231934 seconds ---
# ================================
# Iteration 73:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 186 (ratio = 0.857)
# 本次循环中新训练集大小，占比: 31  (ratio = 0.143)
# --- 0.09043073654174805 seconds ---
# 修剪模型：
# Test scores: maes=14.074, rmse=17.818, r2=0.329
# Val scores: maes=10.712, rmse=13.770, r2=0.283
# --- 0.09114861488342285 seconds ---
# ================================
# Iteration 74:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 188 (ratio = 0.866)
# 本次循环中新训练集大小，占比: 29  (ratio = 0.134)
# --- 0.1029365062713623 seconds ---
# 修剪模型：
# Test scores: maes=12.690, rmse=16.311, r2=0.438
# Val scores: maes=10.048, rmse=13.048, r2=0.369
# --- 0.09580159187316895 seconds ---
# ================================
# Iteration 75:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 190 (ratio = 0.876)
# 本次循环中新训练集大小，占比: 27  (ratio = 0.124)
# --- 0.08893990516662598 seconds ---
# 修剪模型：
# Test scores: maes=14.693, rmse=17.739, r2=0.335
# Val scores: maes=10.997, rmse=13.722, r2=0.306
# --- 0.10361814498901367 seconds ---
# ================================
# Iteration 76:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 192 (ratio = 0.885)
# 本次循环中新训练集大小，占比: 25  (ratio = 0.115)
# --- 0.11441755294799805 seconds ---
# 修剪模型：
# Test scores: maes=12.465, rmse=15.920, r2=0.464
# Val scores: maes=11.399, rmse=14.477, r2=0.256
# --- 0.10436367988586426 seconds ---
# ================================
# Iteration 77:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 194 (ratio = 0.894)
# 本次循环中新训练集大小，占比: 23  (ratio = 0.106)
# --- 0.09052467346191406 seconds ---
# 修剪模型：
# Test scores: maes=12.051, rmse=15.091, r2=0.519
# Val scores: maes=12.241, rmse=15.694, r2=0.117
# --- 0.08864736557006836 seconds ---
# ================================
# Iteration 78:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 196 (ratio = 0.903)
# 本次循环中新训练集大小，占比: 21  (ratio = 0.097)
# --- 0.08695435523986816 seconds ---
# 修剪模型：
# Test scores: maes=13.585, rmse=17.363, r2=0.363
# Val scores: maes=12.592, rmse=16.046, r2=0.073
# --- 0.09213089942932129 seconds ---
# ================================
# Iteration 79:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 198 (ratio = 0.912)
# 本次循环中新训练集大小，占比: 19  (ratio = 0.088)
# --- 0.0980687141418457 seconds ---
# 修剪模型：
# Test scores: maes=15.541, rmse=18.914, r2=0.244
# Val scores: maes=13.511, rmse=16.719, r2=-0.011
# --- 0.10045194625854492 seconds ---

# %%
size_old_val_c, ids_c, test_scores_c, val_scores_c,test_fit_c,remove_c = prune_rd(
        model[c], X_train_val, y_train_val, X_test, y_test,max_iter=80,
        min_drop= 2,threshold=maes_c / 2,train_size= 0.9, file_out=file_out_c)
# Out:
# ================================
# Iteration 0:
# 丢弃训练词条数量 : 10
# 本次循环中 old_val 数量: 0 (ratio = 0.000)
# 本次循环中新训练集大小，占比: 217  (ratio = 1.000)
# --- 0.11216855049133301 seconds ---
# 修剪模型：
# Test scores: maes=6.634, rmse=8.880, r2=0.833
# --- 0.12092208862304688 seconds ---
# ================================
# Iteration 1:
# 丢弃训练词条数量 : 3
# 本次循环中 old_val 数量: 10 (ratio = 0.046)
# 本次循环中新训练集大小，占比: 207  (ratio = 0.954)
# --- 0.102020263671875 seconds ---
# 修剪模型：
# Test scores: maes=6.775, rmse=9.479, r2=0.810
# Val scores: maes=1.548, rmse=1.946, r2=0.980
# --- 0.10779356956481934 seconds ---
# ================================
# Iteration 2:
# 丢弃训练词条数量 : 8
# 本次循环中 old_val 数量: 13 (ratio = 0.060)
# 本次循环中新训练集大小，占比: 204  (ratio = 0.940)
# --- 0.10004234313964844 seconds ---
# 修剪模型：
# Test scores: maes=6.203, rmse=8.553, r2=0.845
# Val scores: maes=1.545, rmse=1.996, r2=0.976
# --- 0.1062767505645752 seconds ---
# ================================
# Iteration 3:
# 丢弃训练词条数量 : 5
# 本次循环中 old_val 数量: 21 (ratio = 0.097)
# 本次循环中新训练集大小，占比: 196  (ratio = 0.903)
# --- 0.09517669677734375 seconds ---
# 修剪模型：
# Test scores: maes=6.530, rmse=8.618, r2=0.843
# Val scores: maes=1.890, rmse=2.605, r2=0.948
# --- 0.10463500022888184 seconds ---
# ================================
# Iteration 4:
# 丢弃训练词条数量 : 7
# 本次循环中 old_val 数量: 26 (ratio = 0.120)
# 本次循环中新训练集大小，占比: 191  (ratio = 0.880)
# --- 0.09647393226623535 seconds ---
# 修剪模型：
# Test scores: maes=7.106, rmse=9.324, r2=0.816
# Val scores: maes=2.786, rmse=3.536, r2=0.905
# --- 0.10045385360717773 seconds ---
# ================================
# Iteration 5:
# 丢弃训练词条数量 : 4
# 本次循环中 old_val 数量: 33 (ratio = 0.152)
# 本次循环中新训练集大小，占比: 184  (ratio = 0.848)
# --- 0.09154987335205078 seconds ---
# 修剪模型：
# Test scores: maes=7.114, rmse=9.541, r2=0.808
# Val scores: maes=2.738, rmse=3.532, r2=0.923
# --- 0.10058045387268066 seconds ---
# ================================
# Iteration 6:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 37 (ratio = 0.171)
# 本次循环中新训练集大小，占比: 180  (ratio = 0.829)
# --- 0.09141898155212402 seconds ---
# 修剪模型：
# Test scores: maes=7.168, rmse=9.682, r2=0.802
# Val scores: maes=2.580, rmse=3.385, r2=0.923
# --- 0.09762358665466309 seconds ---
# ================================
# Iteration 7:
# 丢弃训练词条数量 : 4
# 本次循环中 old_val 数量: 39 (ratio = 0.180)
# 本次循环中新训练集大小，占比: 178  (ratio = 0.820)
# --- 0.09020161628723145 seconds ---
# 修剪模型：
# Test scores: maes=7.233, rmse=9.432, r2=0.812
# Val scores: maes=2.830, rmse=3.457, r2=0.916
# --- 0.09733366966247559 seconds ---
# ================================
# Iteration 8:
# 丢弃训练词条数量 : 6
# 本次循环中 old_val 数量: 43 (ratio = 0.198)
# 本次循环中新训练集大小，占比: 174  (ratio = 0.802)
# --- 0.08922672271728516 seconds ---
# 修剪模型：
# Test scores: maes=6.909, rmse=8.978, r2=0.830
# Val scores: maes=2.382, rmse=2.954, r2=0.947
# --- 0.09468674659729004 seconds ---
# ================================
# Iteration 9:
# 丢弃训练词条数量 : 4
# 本次循环中 old_val 数量: 49 (ratio = 0.226)
# 本次循环中新训练集大小，占比: 168  (ratio = 0.774)
# --- 0.08443713188171387 seconds ---
# 修剪模型：
# Test scores: maes=7.377, rmse=9.867, r2=0.794
# Val scores: maes=2.607, rmse=3.266, r2=0.940
# --- 0.0928659439086914 seconds ---
# ================================
# Iteration 10:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 53 (ratio = 0.244)
# 本次循环中新训练集大小，占比: 164  (ratio = 0.756)
# --- 0.08393001556396484 seconds ---
# 修剪模型：
# Test scores: maes=7.953, rmse=10.166, r2=0.782
# Val scores: maes=2.724, rmse=3.344, r2=0.943
# --- 0.09136795997619629 seconds ---
# ================================
# Iteration 11:
# 丢弃训练词条数量 : 3
# 本次循环中 old_val 数量: 55 (ratio = 0.253)
# 本次循环中新训练集大小，占比: 162  (ratio = 0.747)
# --- 0.08447909355163574 seconds ---
# 修剪模型：
# Test scores: maes=7.056, rmse=9.148, r2=0.823
# Val scores: maes=2.422, rmse=3.233, r2=0.945
# --- 0.08912038803100586 seconds ---
# ================================
# Iteration 12:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 58 (ratio = 0.267)
# 本次循环中新训练集大小，占比: 159  (ratio = 0.733)
# --- 0.08669471740722656 seconds ---
# 修剪模型：
# Test scores: maes=6.845, rmse=9.201, r2=0.821
# Val scores: maes=2.895, rmse=3.690, r2=0.933
# --- 0.08983373641967773 seconds ---
# ================================
# Iteration 13:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 60 (ratio = 0.276)
# 本次循环中新训练集大小，占比: 157  (ratio = 0.724)
# --- 0.08065462112426758 seconds ---
# 修剪模型：
# Test scores: maes=7.844, rmse=10.210, r2=0.780
# Val scores: maes=2.663, rmse=3.537, r2=0.942
# --- 0.08691763877868652 seconds ---
# ================================
# Iteration 14:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 62 (ratio = 0.286)
# 本次循环中新训练集大小，占比: 155  (ratio = 0.714)
# --- 0.08098340034484863 seconds ---
# 修剪模型：
# Test scores: maes=6.526, rmse=9.168, r2=0.822
# Val scores: maes=2.846, rmse=3.608, r2=0.942
# --- 0.08648681640625 seconds ---
# ================================
# Iteration 15:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 64 (ratio = 0.295)
# 本次循环中新训练集大小，占比: 153  (ratio = 0.705)
# --- 0.07854056358337402 seconds ---
# 修剪模型：
# Test scores: maes=7.327, rmse=9.525, r2=0.808
# Val scores: maes=3.027, rmse=3.746, r2=0.936
# --- 0.08649420738220215 seconds ---
# ================================
# Iteration 16:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 66 (ratio = 0.304)
# 本次循环中新训练集大小，占比: 151  (ratio = 0.696)
# --- 0.07945632934570312 seconds ---
# 修剪模型：
# Test scores: maes=6.806, rmse=8.987, r2=0.829
# Val scores: maes=2.985, rmse=3.802, r2=0.933
# --- 0.08605670928955078 seconds ---
# ================================
# Iteration 17:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 68 (ratio = 0.313)
# 本次循环中新训练集大小，占比: 149  (ratio = 0.687)
# --- 0.07995009422302246 seconds ---
# 修剪模型：
# Test scores: maes=7.053, rmse=9.605, r2=0.805
# Val scores: maes=2.731, rmse=3.382, r2=0.954
# --- 0.08472275733947754 seconds ---
# ================================
# Iteration 18:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 70 (ratio = 0.323)
# 本次循环中新训练集大小，占比: 147  (ratio = 0.677)
# --- 0.07665872573852539 seconds ---
# 修剪模型：
# Test scores: maes=7.483, rmse=10.320, r2=0.775
# Val scores: maes=2.936, rmse=3.747, r2=0.945
# --- 0.08400392532348633 seconds ---
# ================================
# Iteration 19:
# 丢弃训练词条数量 : 3
# 本次循环中 old_val 数量: 72 (ratio = 0.332)
# 本次循环中新训练集大小，占比: 145  (ratio = 0.668)
# --- 0.0764157772064209 seconds ---
# 修剪模型：
# Test scores: maes=7.299, rmse=9.707, r2=0.801
# Val scores: maes=3.219, rmse=4.119, r2=0.936
# --- 0.08260631561279297 seconds ---
# ================================
# Iteration 20:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 75 (ratio = 0.346)
# 本次循环中新训练集大小，占比: 142  (ratio = 0.654)
# --- 0.07670164108276367 seconds ---
# 修剪模型：
# Test scores: maes=7.828, rmse=10.074, r2=0.786
# Val scores: maes=3.062, rmse=3.809, r2=0.945
# --- 0.0825502872467041 seconds ---
# ================================
# Iteration 21:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 77 (ratio = 0.355)
# 本次循环中新训练集大小，占比: 140  (ratio = 0.645)
# --- 0.07537484169006348 seconds ---
# 修剪模型：
# Test scores: maes=7.539, rmse=9.687, r2=0.802
# Val scores: maes=3.186, rmse=3.910, r2=0.941
# --- 0.08317112922668457 seconds ---
# ================================
# Iteration 22:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 79 (ratio = 0.364)
# 本次循环中新训练集大小，占比: 138  (ratio = 0.636)
# --- 0.07483267784118652 seconds ---
# 修剪模型：
# Test scores: maes=7.309, rmse=9.347, r2=0.815
# Val scores: maes=3.143, rmse=3.772, r2=0.944
# --- 0.0816946029663086 seconds ---
# ================================
# Iteration 23:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 81 (ratio = 0.373)
# 本次循环中新训练集大小，占比: 136  (ratio = 0.627)
# --- 0.07729625701904297 seconds ---
# 修剪模型：
# Test scores: maes=7.077, rmse=9.164, r2=0.822
# Val scores: maes=2.816, rmse=3.513, r2=0.955
# --- 0.08002948760986328 seconds ---
# ================================
# Iteration 24:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 83 (ratio = 0.382)
# 本次循环中新训练集大小，占比: 134  (ratio = 0.618)
# --- 0.07280278205871582 seconds ---
# 修剪模型：
# Test scores: maes=6.814, rmse=9.151, r2=0.823
# Val scores: maes=3.652, rmse=4.552, r2=0.922
# --- 0.07986140251159668 seconds ---
# ================================
# Iteration 25:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 85 (ratio = 0.392)
# 本次循环中新训练集大小，占比: 132  (ratio = 0.608)
# --- 0.07275247573852539 seconds ---
# 修剪模型：
# Test scores: maes=7.628, rmse=9.998, r2=0.789
# Val scores: maes=3.653, rmse=4.909, r2=0.909
# --- 0.07882499694824219 seconds ---
# ================================
# Iteration 26:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 87 (ratio = 0.401)
# 本次循环中新训练集大小，占比: 130  (ratio = 0.599)
# --- 0.07310152053833008 seconds ---
# 修剪模型：
# Test scores: maes=7.369, rmse=10.195, r2=0.780
# Val scores: maes=3.788, rmse=4.907, r2=0.908
# --- 0.07902240753173828 seconds ---
# ================================
# Iteration 27:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 89 (ratio = 0.410)
# 本次循环中新训练集大小，占比: 128  (ratio = 0.590)
# --- 0.0719144344329834 seconds ---
# 修剪模型：
# Test scores: maes=7.345, rmse=10.081, r2=0.785
# Val scores: maes=3.422, rmse=4.239, r2=0.930
# --- 0.07930874824523926 seconds ---
# ================================
# Iteration 28:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 91 (ratio = 0.419)
# 本次循环中新训练集大小，占比: 126  (ratio = 0.581)
# --- 0.07371211051940918 seconds ---
# 修剪模型：
# Test scores: maes=7.275, rmse=9.766, r2=0.798
# Val scores: maes=4.095, rmse=5.154, r2=0.900
# --- 0.07892012596130371 seconds ---
# ================================
# Iteration 29:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 93 (ratio = 0.429)
# 本次循环中新训练集大小，占比: 124  (ratio = 0.571)
# --- 0.07088470458984375 seconds ---
# 修剪模型：
# Test scores: maes=7.031, rmse=9.568, r2=0.807
# Val scores: maes=3.765, rmse=4.689, r2=0.917
# --- 0.07598590850830078 seconds ---
# ================================
# Iteration 30:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 95 (ratio = 0.438)
# 本次循环中新训练集大小，占比: 122  (ratio = 0.562)
# --- 0.06900978088378906 seconds ---
# 修剪模型：
# Test scores: maes=7.681, rmse=10.116, r2=0.784
# Val scores: maes=3.833, rmse=4.829, r2=0.910
# --- 0.0753486156463623 seconds ---
# ================================
# Iteration 31:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 97 (ratio = 0.447)
# 本次循环中新训练集大小，占比: 120  (ratio = 0.553)
# --- 0.0684361457824707 seconds ---
# 修剪模型：
# Test scores: maes=7.017, rmse=9.586, r2=0.806
# Val scores: maes=3.937, rmse=4.707, r2=0.914
# --- 0.07424306869506836 seconds ---
# ================================
# Iteration 32:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 99 (ratio = 0.456)
# 本次循环中新训练集大小，占比: 118  (ratio = 0.544)
# --- 0.06744885444641113 seconds ---
# 修剪模型：
# Test scores: maes=7.041, rmse=9.150, r2=0.823
# Val scores: maes=3.799, rmse=4.766, r2=0.910
# --- 0.07447147369384766 seconds ---
# ================================
# Iteration 33:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 101 (ratio = 0.465)
# 本次循环中新训练集大小，占比: 116  (ratio = 0.535)
# --- 0.06620168685913086 seconds ---
# 修剪模型：
# Test scores: maes=6.519, rmse=8.965, r2=0.830
# Val scores: maes=3.848, rmse=4.780, r2=0.908
# --- 0.0723567008972168 seconds ---
# ================================
# Iteration 34:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 103 (ratio = 0.475)
# 本次循环中新训练集大小，占比: 114  (ratio = 0.525)
# --- 0.06815171241760254 seconds ---
# 修剪模型：
# Test scores: maes=7.544, rmse=10.026, r2=0.788
# Val scores: maes=4.090, rmse=4.911, r2=0.904
# --- 0.07218647003173828 seconds ---
# ================================
# Iteration 35:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 105 (ratio = 0.484)
# 本次循环中新训练集大小，占比: 112  (ratio = 0.516)
# --- 0.06692075729370117 seconds ---
# 修剪模型：
# Test scores: maes=6.951, rmse=9.265, r2=0.819
# Val scores: maes=4.389, rmse=5.122, r2=0.894
# --- 0.07221555709838867 seconds ---
# ================================
# Iteration 36:
# 丢弃训练词条数量 : 4
# 本次循环中 old_val 数量: 107 (ratio = 0.493)
# 本次循环中新训练集大小，占比: 110  (ratio = 0.507)
# --- 0.06603074073791504 seconds ---
# 修剪模型：
# Test scores: maes=7.470, rmse=9.604, r2=0.805
# Val scores: maes=4.196, rmse=5.033, r2=0.904
# --- 0.0704948902130127 seconds ---
# ================================
# Iteration 37:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 111 (ratio = 0.512)
# 本次循环中新训练集大小，占比: 106  (ratio = 0.488)
# --- 0.06324625015258789 seconds ---
# 修剪模型：
# Test scores: maes=7.102, rmse=9.471, r2=0.810
# Val scores: maes=4.446, rmse=5.175, r2=0.896
# --- 0.06850719451904297 seconds ---
# ================================
# Iteration 38:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 113 (ratio = 0.521)
# 本次循环中新训练集大小，占比: 104  (ratio = 0.479)
# --- 0.06387639045715332 seconds ---
# 修剪模型：
# Test scores: maes=7.901, rmse=9.875, r2=0.794
# Val scores: maes=4.321, rmse=5.142, r2=0.896
# --- 0.06909608840942383 seconds ---
# ================================
# Iteration 39:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 115 (ratio = 0.530)
# 本次循环中新训练集大小，占比: 102  (ratio = 0.470)
# --- 0.06261396408081055 seconds ---
# 修剪模型：
# Test scores: maes=7.428, rmse=10.029, r2=0.787
# Val scores: maes=4.392, rmse=5.152, r2=0.899
# --- 0.06791210174560547 seconds ---
# ================================
# Iteration 40:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 117 (ratio = 0.539)
# 本次循环中新训练集大小，占比: 100  (ratio = 0.461)
# --- 0.06200766563415527 seconds ---
# 修剪模型：
# Test scores: maes=7.535, rmse=9.754, r2=0.799
# Val scores: maes=4.334, rmse=5.216, r2=0.896
# --- 0.06719827651977539 seconds ---
# ================================
# Iteration 41:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 119 (ratio = 0.548)
# 本次循环中新训练集大小，占比: 98  (ratio = 0.452)
# --- 0.060700178146362305 seconds ---
# 修剪模型：
# Test scores: maes=7.681, rmse=10.389, r2=0.772
# Val scores: maes=4.109, rmse=5.311, r2=0.891
# --- 0.06596231460571289 seconds ---
# ================================
# Iteration 42:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 121 (ratio = 0.558)
# 本次循环中新训练集大小，占比: 96  (ratio = 0.442)
# --- 0.06110858917236328 seconds ---
# 修剪模型：
# Test scores: maes=7.629, rmse=9.765, r2=0.798
# Val scores: maes=4.605, rmse=5.630, r2=0.876
# --- 0.06632351875305176 seconds ---
# ================================
# Iteration 43:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 123 (ratio = 0.567)
# 本次循环中新训练集大小，占比: 94  (ratio = 0.433)
# --- 0.06087040901184082 seconds ---
# 修剪模型：
# Test scores: maes=7.863, rmse=9.824, r2=0.796
# Val scores: maes=5.230, rmse=6.533, r2=0.830
# --- 0.06601428985595703 seconds ---
# ================================
# Iteration 44:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 125 (ratio = 0.576)
# 本次循环中新训练集大小，占比: 92  (ratio = 0.424)
# --- 0.05934286117553711 seconds ---
# 修剪模型：
# Test scores: maes=8.364, rmse=10.374, r2=0.773
# Val scores: maes=4.983, rmse=6.291, r2=0.842
# --- 0.06342458724975586 seconds ---
# ================================
# Iteration 45:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 127 (ratio = 0.585)
# 本次循环中新训练集大小，占比: 90  (ratio = 0.415)
# --- 0.057282447814941406 seconds ---
# 修剪模型：
# Test scores: maes=7.896, rmse=10.294, r2=0.776
# Val scores: maes=4.782, rmse=6.045, r2=0.852
# --- 0.062262773513793945 seconds ---
# ================================
# Iteration 46:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 129 (ratio = 0.594)
# 本次循环中新训练集大小，占比: 88  (ratio = 0.406)
# --- 0.05646705627441406 seconds ---
# 修剪模型：
# Test scores: maes=7.357, rmse=9.613, r2=0.805
# Val scores: maes=4.926, rmse=6.153, r2=0.845
# --- 0.06135153770446777 seconds ---
# ================================
# Iteration 47:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 131 (ratio = 0.604)
# 本次循环中新训练集大小，占比: 86  (ratio = 0.396)
# --- 0.056833505630493164 seconds ---
# 修剪模型：
# Test scores: maes=8.232, rmse=10.503, r2=0.767
# Val scores: maes=5.314, rmse=6.372, r2=0.833
# --- 0.0619359016418457 seconds ---
# ================================
# Iteration 48:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 133 (ratio = 0.613)
# 本次循环中新训练集大小，占比: 84  (ratio = 0.387)
# --- 0.05623221397399902 seconds ---
# 修剪模型：
# Test scores: maes=7.934, rmse=10.040, r2=0.787
# Val scores: maes=5.354, rmse=6.686, r2=0.813
# --- 0.05985665321350098 seconds ---
# ================================
# Iteration 49:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 135 (ratio = 0.622)
# 本次循环中新训练集大小，占比: 82  (ratio = 0.378)
# --- 0.054372549057006836 seconds ---
# 修剪模型：
# Test scores: maes=7.316, rmse=9.893, r2=0.793
# Val scores: maes=5.236, rmse=6.488, r2=0.823
# --- 0.05865740776062012 seconds ---
# ================================
# Iteration 50:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 137 (ratio = 0.631)
# 本次循环中新训练集大小，占比: 80  (ratio = 0.369)
# --- 0.054836273193359375 seconds ---
# 修剪模型：
# Test scores: maes=7.153, rmse=9.422, r2=0.812
# Val scores: maes=5.232, rmse=6.457, r2=0.827
# --- 0.05911421775817871 seconds ---
# ================================
# Iteration 51:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 139 (ratio = 0.641)
# 本次循环中新训练集大小，占比: 78  (ratio = 0.359)
# --- 0.05271768569946289 seconds ---
# 修剪模型：
# Test scores: maes=6.926, rmse=9.743, r2=0.799
# Val scores: maes=5.639, rmse=6.849, r2=0.803
# --- 0.05692434310913086 seconds ---
# ================================
# Iteration 52:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 141 (ratio = 0.650)
# 本次循环中新训练集大小，占比: 76  (ratio = 0.350)
# --- 0.053209543228149414 seconds ---
# 修剪模型：
# Test scores: maes=8.439, rmse=11.007, r2=0.744
# Val scores: maes=5.122, rmse=6.363, r2=0.833
# --- 0.05729389190673828 seconds ---
# ================================
# Iteration 53:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 143 (ratio = 0.659)
# 本次循环中新训练集大小，占比: 74  (ratio = 0.341)
# --- 0.051964521408081055 seconds ---
# 修剪模型：
# Test scores: maes=8.866, rmse=11.338, r2=0.728
# Val scores: maes=5.727, rmse=7.013, r2=0.798
# --- 0.05590105056762695 seconds ---
# ================================
# Iteration 54:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 145 (ratio = 0.668)
# 本次循环中新训练集大小，占比: 72  (ratio = 0.332)
# --- 0.05099225044250488 seconds ---
# 修剪模型：
# Test scores: maes=7.340, rmse=9.949, r2=0.791
# Val scores: maes=5.743, rmse=7.165, r2=0.790
# --- 0.056960105895996094 seconds ---
# ================================
# Iteration 55:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 147 (ratio = 0.677)
# 本次循环中新训练集大小，占比: 70  (ratio = 0.323)
# --- 0.05043387413024902 seconds ---
# 修剪模型：
# Test scores: maes=8.443, rmse=10.846, r2=0.751
# Val scores: maes=5.764, rmse=7.039, r2=0.803
# --- 0.05464768409729004 seconds ---
# ================================
# Iteration 56:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 149 (ratio = 0.687)
# 本次循环中新训练集大小，占比: 68  (ratio = 0.313)
# --- 0.05221700668334961 seconds ---
# 修剪模型：
# Test scores: maes=8.472, rmse=11.081, r2=0.741
# Val scores: maes=6.625, rmse=8.056, r2=0.740
# --- 0.05379343032836914 seconds ---
# ================================
# Iteration 57:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 151 (ratio = 0.696)
# 本次循环中新训练集大小，占比: 66  (ratio = 0.304)
# --- 0.04850959777832031 seconds ---
# 修剪模型：
# Test scores: maes=9.108, rmse=11.587, r2=0.716
# Val scores: maes=6.344, rmse=7.796, r2=0.753
# --- 0.05242919921875 seconds ---
# ================================
# Iteration 58:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 153 (ratio = 0.705)
# 本次循环中新训练集大小，占比: 64  (ratio = 0.295)
# --- 0.04717063903808594 seconds ---
# 修剪模型：
# Test scores: maes=8.542, rmse=11.008, r2=0.744
# Val scores: maes=6.636, rmse=8.274, r2=0.721
# --- 0.052256107330322266 seconds ---
# ================================
# Iteration 59:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 155 (ratio = 0.714)
# 本次循环中新训练集大小，占比: 62  (ratio = 0.286)
# --- 0.04691362380981445 seconds ---
# 修剪模型：
# Test scores: maes=8.974, rmse=11.866, r2=0.702
# Val scores: maes=7.053, rmse=8.744, r2=0.689
# --- 0.05038332939147949 seconds ---
# ================================
# Iteration 60:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 157 (ratio = 0.724)
# 本次循环中新训练集大小，占比: 60  (ratio = 0.276)
# --- 0.045845985412597656 seconds ---
# 修剪模型：
# Test scores: maes=8.968, rmse=11.232, r2=0.733
# Val scores: maes=6.719, rmse=8.342, r2=0.714
# --- 0.04999089241027832 seconds ---
# ================================
# Iteration 61:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 159 (ratio = 0.733)
# 本次循环中新训练集大小，占比: 58  (ratio = 0.267)
# --- 0.04644298553466797 seconds ---
# 修剪模型：
# Test scores: maes=9.697, rmse=12.207, r2=0.685
# Val scores: maes=7.187, rmse=8.928, r2=0.669
# --- 0.04917335510253906 seconds ---
# ================================
# Iteration 62:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 161 (ratio = 0.742)
# 本次循环中新训练集大小，占比: 56  (ratio = 0.258)
# --- 0.04553556442260742 seconds ---
# 修剪模型：
# Test scores: maes=8.802, rmse=11.177, r2=0.736
# Val scores: maes=6.670, rmse=8.628, r2=0.688
# --- 0.04951071739196777 seconds ---
# ================================
# Iteration 63:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 163 (ratio = 0.751)
# 本次循环中新训练集大小，占比: 54  (ratio = 0.249)
# --- 0.04462170600891113 seconds ---
# 修剪模型：
# Test scores: maes=9.792, rmse=12.326, r2=0.679
# Val scores: maes=7.438, rmse=9.317, r2=0.638
# --- 0.048898935317993164 seconds ---
# ================================
# Iteration 64:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 165 (ratio = 0.760)
# 本次循环中新训练集大小，占比: 52  (ratio = 0.240)
# --- 0.043759822845458984 seconds ---
# 修剪模型：
# Test scores: maes=8.906, rmse=11.173, r2=0.736
# Val scores: maes=8.085, rmse=9.901, r2=0.598
# --- 0.04920077323913574 seconds ---
# ================================
# Iteration 65:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 167 (ratio = 0.770)
# 本次循环中新训练集大小，占比: 50  (ratio = 0.230)
# --- 0.04241037368774414 seconds ---
# 修剪模型：
# Test scores: maes=9.404, rmse=12.091, r2=0.691
# Val scores: maes=8.002, rmse=10.071, r2=0.588
# --- 0.04653453826904297 seconds ---
# ================================
# Iteration 66:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 169 (ratio = 0.779)
# 本次循环中新训练集大小，占比: 48  (ratio = 0.221)
# --- 0.0430145263671875 seconds ---
# 修剪模型：
# Test scores: maes=10.022, rmse=12.277, r2=0.681
# Val scores: maes=7.502, rmse=9.374, r2=0.645
# --- 0.0449063777923584 seconds ---
# ================================
# Iteration 67:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 171 (ratio = 0.788)
# 本次循环中新训练集大小，占比: 46  (ratio = 0.212)
# --- 0.04111194610595703 seconds ---
# 修剪模型：
# Test scores: maes=11.113, rmse=13.342, r2=0.624
# Val scores: maes=8.712, rmse=10.528, r2=0.551
# --- 0.044675588607788086 seconds ---
# ================================
# Iteration 68:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 173 (ratio = 0.797)
# 本次循环中新训练集大小，占比: 44  (ratio = 0.203)
# --- 0.03985714912414551 seconds ---
# 修剪模型：
# Test scores: maes=9.188, rmse=11.375, r2=0.727
# Val scores: maes=7.580, rmse=9.431, r2=0.639
# --- 0.04396176338195801 seconds ---
# ================================
# Iteration 69:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 175 (ratio = 0.806)
# 本次循环中新训练集大小，占比: 42  (ratio = 0.194)
# --- 0.04008340835571289 seconds ---
# 修剪模型：
# Test scores: maes=10.849, rmse=13.698, r2=0.603
# Val scores: maes=8.374, rmse=10.939, r2=0.528
# --- 0.042268991470336914 seconds ---
# ================================
# Iteration 70:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 177 (ratio = 0.816)
# 本次循环中新训练集大小，占比: 40  (ratio = 0.184)
# --- 0.038910865783691406 seconds ---
# 修剪模型：
# Test scores: maes=10.979, rmse=13.023, r2=0.642
# Val scores: maes=8.939, rmse=11.315, r2=0.500
# --- 0.041414737701416016 seconds ---
# ================================
# Iteration 71:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 179 (ratio = 0.825)
# 本次循环中新训练集大小，占比: 38  (ratio = 0.175)
# --- 0.037148237228393555 seconds ---
# 修剪模型：
# Test scores: maes=10.357, rmse=12.226, r2=0.684
# Val scores: maes=10.458, rmse=13.415, r2=0.298
# --- 0.0419161319732666 seconds ---
# ================================
# Iteration 72:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 181 (ratio = 0.834)
# 本次循环中新训练集大小，占比: 36  (ratio = 0.166)
# --- 0.0368497371673584 seconds ---
# 修剪模型：
# Test scores: maes=11.796, rmse=13.911, r2=0.591
# Val scores: maes=12.138, rmse=15.608, r2=0.051
# --- 0.03971552848815918 seconds ---
# ================================
# Iteration 73:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 183 (ratio = 0.843)
# 本次循环中新训练集大小，占比: 34  (ratio = 0.157)
# --- 0.03577566146850586 seconds ---
# 修剪模型：
# Test scores: maes=13.347, rmse=16.627, r2=0.416
# Val scores: maes=11.285, rmse=13.873, r2=0.251
# --- 0.03859114646911621 seconds ---
# ================================
# Iteration 74:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 185 (ratio = 0.853)
# 本次循环中新训练集大小，占比: 32  (ratio = 0.147)
# --- 0.03470206260681152 seconds ---
# 修剪模型：
# Test scores: maes=11.440, rmse=15.075, r2=0.520
# Val scores: maes=10.310, rmse=12.855, r2=0.351
# --- 0.038721561431884766 seconds ---
# ================================
# Iteration 75:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 187 (ratio = 0.862)
# 本次循环中新训练集大小，占比: 30  (ratio = 0.138)
# --- 0.03481316566467285 seconds ---
# 修剪模型：
# Test scores: maes=12.970, rmse=15.955, r2=0.462
# Val scores: maes=11.210, rmse=13.884, r2=0.240
# --- 0.038095712661743164 seconds ---
# ================================
# Iteration 76:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 189 (ratio = 0.871)
# 本次循环中新训练集大小，占比: 28  (ratio = 0.129)
# --- 0.033499717712402344 seconds ---
# 修剪模型：
# Test scores: maes=14.060, rmse=17.108, r2=0.381
# Val scores: maes=11.788, rmse=14.634, r2=0.174
# --- 0.03557443618774414 seconds ---
# ================================
# Iteration 77:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 191 (ratio = 0.880)
# 本次循环中新训练集大小，占比: 26  (ratio = 0.120)
# --- 0.034348487854003906 seconds ---
# 修剪模型：
# Test scores: maes=12.381, rmse=14.977, r2=0.526
# Val scores: maes=11.403, rmse=14.118, r2=0.246
# --- 0.03697657585144043 seconds ---
# ================================
# Iteration 78:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 193 (ratio = 0.889)
# 本次循环中新训练集大小，占比: 24  (ratio = 0.111)
# --- 0.031212568283081055 seconds ---
# 修剪模型：
# Test scores: maes=11.742, rmse=14.182, r2=0.575
# Val scores: maes=12.410, rmse=14.674, r2=0.189
# --- 0.03417491912841797 seconds ---
# ================================
# Iteration 79:
# 丢弃训练词条数量 : 2
# 本次循环中 old_val 数量: 195 (ratio = 0.899)
# 本次循环中新训练集大小，占比: 22  (ratio = 0.101)
# --- 0.03085923194885254 seconds ---
# 修剪模型：
# Test scores: maes=13.371, rmse=15.718, r2=0.478
# Val scores: maes=13.422, rmse=16.613, r2=-0.032
# --- 0.03293776512145996 seconds ---

# %%
from prepare import get_mse_rmse_mae_mape_smape_r2
import os
from matplotlib import pyplot as plt
import seaborn as sns
from matplotlib.ticker import MultipleLocator

def draw_scatter_1(train_true, train_pred, val_true, val_pred,
                   test_true, test_pred, title,
                   test_lower=None, test_upper=None,
                   actual_text='actual', pred_text='prediction',
                   save=False):
    """
    绘制三组数据的散点图（训练集、验证集、测试集）
    仅在测试集上添加误差区间和误差棒
    """

    # 统一字体设置
    plt.rcParams['font.family'] = 'Times New Roman'

    # 转成一维数组，避免 pandas / ndarray 混用出错
    train_true = np.asarray(train_true).ravel()
    train_pred = np.asarray(train_pred).ravel()
    val_true = np.asarray(val_true).ravel()
    val_pred = np.asarray(val_pred).ravel()
    test_true = np.asarray(test_true).ravel()
    test_pred = np.asarray(test_pred).ravel()

    if test_lower is not None:
        test_lower = np.asarray(test_lower).ravel()
    if test_upper is not None:
        test_upper = np.asarray(test_upper).ravel()

    # 创建图形
    fig, ax = plt.subplots(figsize=(10, 8))

    # 定义字体样式
    font_common = {
        'family': 'Times New Roman',
        'color': '#2F4F4F',
        'weight': 'bold',
        'size': 18
    }
    legend_font = {'family': 'Times New Roman', 'weight': 'bold', 'size': 15}

    # ===== 先画训练集、验证集回归散点图（基础内容不变）=====
    sns.regplot(x=train_true, y=train_pred,
                color="dodgerblue", label='train',
                scatter_kws={'alpha': 0.5, 's': 18},
                ax=ax)

    sns.regplot(x=val_true, y=val_pred,
                color="orange", label="val",
                scatter_kws={'alpha': 0.5, 's': 10},
                ax=ax)

    sns.regplot(x=test_true, y=test_pred,
                color='#FF69B4', label='test',
                scatter_kws={'alpha': 0.8, 's': 30},
                ax=ax)

    # ===== 只对测试集添加误差区间和误差棒 =====
    if test_lower is not None and test_upper is not None:
        # 按真实值排序，保证阴影区间平滑
        sorted_idx = np.argsort(test_true)
        test_true_sorted = test_true[sorted_idx]
        test_pred_sorted = test_pred[sorted_idx]
        lower_sorted = test_lower[sorted_idx]
        upper_sorted = test_upper[sorted_idx]

        # 计算误差棒上下长度
        yerr_lower = np.maximum(test_pred_sorted - lower_sorted, 0)
        yerr_upper = np.maximum(upper_sorted - test_pred_sorted, 0)

        # 置信区间阴影
        ax.fill_between(
            test_true_sorted,
            lower_sorted,
            upper_sorted,
            color='lightgray',
            alpha=0.5,
            label='95% Confidence Interval',
            zorder=1
        )

        # 误差棒
        ax.errorbar(
            test_true_sorted,
            test_pred_sorted,
            yerr=[yerr_lower, yerr_upper],
            fmt='o',
            markersize=4,
            color='#FF69B4',
            ecolor='gray',
            elinewidth=1,
            capsize=3,
            alpha=0.7,
            zorder=2
        )

    # ===== 坐标轴标签和范围 =====
    ax.set_xlabel(actual_text, fontdict=font_common, weight='bold')
    ax.set_ylabel(pred_text, fontdict=font_common, weight='bold')
    ax.set_xlim(15, 95)
    ax.set_ylim(15, 95)

    # 图例
    ax.legend(loc="lower right", markerscale=1.5, prop=legend_font,
              frameon=True)

    # 刻度
    ax.tick_params(axis='both', which='major', direction='out',
                   width=2, labelsize=16,
                   bottom=True, top=False, left=True, right=False)
    ax.tick_params(axis='both', which='minor', direction='out',
                   bottom=True, top=False, left=True, right=False)
    for label in ax.get_xticklabels() + ax.get_yticklabels():
        label.set_fontsize(16)      # 放大字体
        label.set_fontweight('bold')  # 加粗
        label.set_family('Times New Roman')
    ax.xaxis.set_major_locator(MultipleLocator(10))
    ax.yaxis.set_major_locator(MultipleLocator(10))
    ax.xaxis.set_minor_locator(MultipleLocator(10))
    ax.yaxis.set_minor_locator(MultipleLocator(10))

    # 背景和边框
    ax.set_facecolor('white')
    for spine in ax.spines.values():
        spine.set_linewidth(3)
        spine.set_edgecolor('black')

    # 网格
    ax.grid(True, axis='both', linestyle='--',
            linewidth=0.5, color='gray', alpha=0.6)

    # ===== 统计信息 =====
    _, _, _, _, _, train_r2 = get_mse_rmse_mae_mape_smape_r2(
        train_true / 100, train_pred / 100
    )
    _, _, _, _, _, val_r2 = get_mse_rmse_mae_mape_smape_r2(
        val_true / 100, val_pred / 100
    )
    _, _, _, _, _, test_r2 = get_mse_rmse_mae_mape_smape_r2(
        test_true / 100, test_pred / 100
    )

    ax.text(20, 86, f"Train R² = {train_r2:.3f}", **font_common)
    ax.text(20, 80, f"val   R² = {val_r2:.3f}", **font_common)
    ax.text(20, 74, f"test  R² = {test_r2:.3f}", **font_common)

    # 标题
    ax.text(50, 90, title, **font_common, horizontalalignment="center")

    # 保存
    if save:
        out_put = 'prune3'
        if not os.path.exists(out_put):
            os.makedirs(out_put)
        output_path = os.path.join(out_put, f'{title}.jpg')
        plt.savefig(output_path, format="jpg", dpi=600,
                    bbox_inches="tight",
                    pil_kwargs={'quality': 95})
        print(f"测试图已保存：{output_path}")

    plt.tight_layout()
    plt.show()

# %%
a_test_70 = list(set(ids_a['train_val']) - set(remove_a[14]))
b_test_70 = list(set(ids_b['train_val']) - set(remove_b[14]))
c_test_70 = list(set(ids_c['train_val']) - set(remove_c[16]))

# %%
df_a = df.loc[remove_a[14]]
X_train_val = df_a.drop(columns=['NO(%)'])
y_train_val = df_a['NO(%)']
df_a_val = df.loc[a_test_70]
X_val = df_a_val.drop(columns=['NO(%)'])
y_val = df_a_val['NO(%)']
train_pred, val_pred = process_regressor(model[a],X_train_val,X_val,y_train_val,y_val,cv=False)
_,test_pred = process_regressor(model[a],X_train_val,X_test,y_train_val,y_test,cv=False)
model_performance_metrics('Cat Train 70%', y_train_val, train_pred)
model_performance_metrics('Cat val 30%', y_val, val_pred)
model_performance_metrics('Cat test', y_test, test_pred)
draw_scatter_1(y_train_val, train_pred, y_val,val_pred,y_test, test_pred, "Catboost prune 70%", actual_text='Actual NO removal (%)',test_lower=None,test_upper=None,pred_text='Predicted NO removal (%)',save=True)
# Out:
# Cat Train 70% mse: 0.00009 | rmse: 0.00941 | mae: 0.00744 | mape: 1.92128 | smape: 1.90267 | r2: 0.99742
#
# Cat val 30% mse: 0.00125 | rmse: 0.03530 | mae: 0.02833 | mape: 7.88864 | smape: 7.53061 | r2: 0.93412
#
# Cat test mse: 0.00708 | rmse: 0.08415 | mae: 0.06440 | mape: 17.36607 | smape: 14.95562 | r2: 0.85035
#
# 测试图已保存：prune3\Catboost prune 70%.jpg

# %%
df_b = df.loc[remove_b[14]]
X_train_val = df_b.drop(columns=['NO(%)'])
y_train_val = df_b['NO(%)']
df_b_val = df.loc[b_test_70]
X_val = df_b_val.drop(columns=['NO(%)'])
y_val = df_b_val['NO(%)']
train_pred, val_pred = process_regressor(model[b],X_train_val,X_val,y_train_val,y_val)
_,test_pred = process_regressor(model[b],X_train_val,X_test,y_train_val,y_test)
model_performance_metrics('XGB Train 70%', y_train_val, train_pred)
model_performance_metrics('XGB val 30%', y_val, val_pred)
model_performance_metrics('XGB test', y_test, test_pred)
draw_scatter_1(y_train_val, train_pred, y_val,val_pred,y_test, test_pred, "XGBboost prune 70%", actual_text='Actual NO removal (%)',test_lower=None,test_upper=None,pred_text='Predicted NO removal (%)',save=True)
# Out:
# cv train R2: -0.064 (+/- 0.492)
#
# cv train R2: -0.064 (+/- 0.492)
#
# XGB Train 70% mse: 0.00049 | rmse: 0.02221 | mae: 0.01742 | mape: 4.48636 | smape: 4.40782 | r2: 0.98510
#
# XGB val 30% mse: 0.00135 | rmse: 0.03676 | mae: 0.03041 | mape: 8.51888 | smape: 8.32814 | r2: 0.93736
#
# XGB test mse: 0.00687 | rmse: 0.08289 | mae: 0.06875 | mape: 19.02644 | smape: 17.02513 | r2: 0.85478
#
# 测试图已保存：prune3\XGBboost prune 70%.jpg

# %%
df_c = df.loc[remove_c[16]]
X_train_val = df_c.drop(columns=['NO(%)'])
y_train_val = df_c['NO(%)']
df_c_val = df.loc[c_test_70]
X_val = df_c_val.drop(columns=['NO(%)'])
y_val = df_c_val['NO(%)']
train_pred, val_pred = process_regressor(model[c],X_train_val,X_val,y_train_val,y_val,cv=True)
_,test_pred = process_regressor(model[c],X_train_val,X_test,y_train_val,y_test,cv=True)
model_performance_metrics('GradientBoost Train 70%', y_train_val, train_pred)
model_performance_metrics('GradientBoost val 30%', y_val, val_pred)
model_performance_metrics('GradientBoost test', y_test, test_pred)
draw_scatter_1(y_train_val, train_pred, y_val,val_pred,y_test, test_pred, "GradientBoost prune 70%", actual_text='Actual NO removal (%)',test_lower=None,test_upper=None,pred_text='Predicted NO removal (%)',save=True)
# Out:
# cv train R2: -0.086 (+/- 0.235)
#
# cv train R2: -0.086 (+/- 0.235)
#
# GradientBoost Train 70% mse: 0.00001 | rmse: 0.00311 | mae: 0.00251 | mape: 0.64220 | smape: 0.64056 | r2: 0.99971
#
# GradientBoost val 30% mse: 0.00145 | rmse: 0.03802 | mae: 0.02985 | mape: 7.84475 | smape: 7.74447 | r2: 0.93271
#
# GradientBoost test mse: 0.00808 | rmse: 0.08987 | mae: 0.06806 | mape: 19.32156 | smape: 16.50409 | r2: 0.82929
#
# 测试图已保存：prune3\GradientBoost prune 70%.jpg
