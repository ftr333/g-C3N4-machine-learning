# %%
import pandas as pd
df_1 = pd.read_csv('100%.csv')
df_2 = pd.read_csv('70%.csv')

# %%
from prepare import draw_violin_concatenate
from config import violin_config_concatenate

# %%
for key in violin_config_concatenate:
    draw_violin_concatenate(df_1, df_2, violin_config_concatenate,key,'BBBBBBBB',save=True)
# Out:
# D:\g-C3N4降解NO\prepare.py:545: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(
# 小提琴图已保存：violin_images\50_NOxBBBBBBBB.jpg
# D:\g-C3N4降解NO\prepare.py:545: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(
# 小提琴图已保存：violin_images\50_BETBBBBBBBB.jpg
# D:\g-C3N4降解NO\prepare.py:545: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(
# 小提琴图已保存：violin_images\50_EgBBBBBBBB.jpg
# D:\g-C3N4降解NO\prepare.py:545: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(
# 小提琴图已保存：violin_images\50_NO2BBBBBBBB.jpg
# ...
